# %% [markdown]
# # Dueling DQN
#
# ## 1. 相关概念
#
# #### 最优状态价值函数 (optimal state-value function):
#
# $V_*(s) = \max_\pi V_\pi (s), \forall s \in \mathcal{S}$。
#
# #### 最优优势函数 (optimal advantage function):
#
# $A_*(s, a) = Q_*(s, a) - V_*(s)$。可得到: $Q_*(s, a) = V_*(s) + A_*(s, a) - \max_{a \in \mathcal{A}} A_*(s, a), \forall s \in \mathcal{S}, a \in \mathcal{A}$。其中，$\max_{a \in \mathcal{A}} A_*(s, a) = 0, \forall s \in \mathcal{S}$。
#
# #### 对决网络 (dueling network):
#
# 由两部分组成，$A(s, a; w^A)$近似最优优势函数$A_*(s, a)$，$V(s; w^V)$近似最优状态价值函数$V_*(s)$，对决网络定义为$Q(s, a; w) = V(s; w^V) + A(s, a; w^A) - \max_{a \in \mathcal{A}} A(s, a; w^A)$。直观上，对决网络可以了解哪些状态有价值或没价值而无需考虑动作；实践中，对决网络比DQN可取得更好的效果。
#
# #### 网络结构:
#
# 两个网络共享embedding层，将状态$s$映射成特征向量。(1) 优势头输出向量的大小是动作空间的维度$\mid \mathcal{A} \mid$，每个元素对应一个动作；(2) 状态价值头输出一个实数。
#
# ## 2. 不唯一性
#
# $\max_{a \in \mathcal{A}} A_*(s, a) = 0, \forall s \in \mathcal{S}$，但是从对决网络中删去。若删掉，$Q_*(s, a) = V_*(s) + A_*(s, a)$，$V$和$A$会不唯一，例如$V$增加1，$A$减少1。从而对决网络最后一项不可省略。
#
# ## 3. 对决网络的实现
#
# 实际中，会使用$Q(s, a; w) = V(s; w^V) + A(s, a; w^A) - \text{mean}_{a \in \mathcal{A}} A(s, a; w^A)$，原因如下:
#
# (1) 取max会造成梯度不稳定，取mean梯度会更平滑，减少max操作带来的剧烈变化和不稳定性。
#
# (2) 取mean可以减少方差，平滑掉一些噪声，从而使模型效果更好。
#
# (3) 取max会过于集中在一个动作上，而取mean会减少偏向，有利于探索更多策略。
#
# ## 4. 训练流程
#
# 训练流程与DQN相同。
#
# # 代码实现

# %%
# 导入库
import os
import gym
import argparse
import numpy as np

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

# %%
# 定义Dueling Q-Network
class Dueling_QNet(nn.Module):
    def __init__(self, state_size, num_actions):
        super().__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 32)
        self.V = nn.Linear(32, 1)
        self.A = nn.Linear(32, num_actions)
        
    def forward(self, state):
        # state: (batch_size, state_size)
        x = F.relu(self.fc1(state.float()))
        x = F.relu(self.fc2(x))
        # V: (batch_size, 1)
        V = self.V(x)
        # A: (batch_size, num_actions)
        A = self.A(x)
        return V + A - torch.mean(A, dim=-1, keepdim=True)

# %%
# 定义Dueling DQN类
class DuelingDQN:
    def __init__(self, state_size, num_actions, gamma, device):
        self.gamma = gamma
        self.Q = Dueling_QNet(state_size, num_actions).to(device)
        self.target_Q = Dueling_QNet(state_size, num_actions).to(device)
        self.target_Q.load_state_dict(self.Q.state_dict())
        
    def get_action(self, state):
        # state: (state_size,)
        # qvals: (num_actions,)
        qvals = self.Q(state)
        return qvals.argmax().item()
    
    def compute_loss(self, bs, ba, br, bd, bns):
        # bs, bns: (batch_size, state_size)
        # ba, br, bd: (batch_size,)
        # qvals, next_qvals: (batch_size,)
        qvals = self.Q(bs).gather(1, ba.unsqueeze(1)).squeeze(1)
        # next_actions: (batch_size, 1)
        next_actions = self.Q(bns).argmax(dim=1, keepdim=True)
        # detach() 避免对目标网络的参数求导
        next_qvals = self.target_Q(bns).gather(1, next_actions).squeeze(1).detach()
        loss = F.mse_loss(qvals, br + self.gamma * next_qvals * (1 - bd))
        return loss        
    
    def soft_update(self, tau=0.01):
        for target_param, param in zip(self.target_Q.parameters(), self.Q.parameters()):
            target_param.data.copy_(param.data * tau + target_param.data * (1 - tau))

# %%
# 定义经验缓存
class ReplayBuffer:
    def __init__(self, max_size, device):
        self.max_size = max_size
        self.device = device
        self.size = 0
        self.state = []
        self.action = []
        self.reward = []
        self.done = []
        self.next_state = []
        
    def push(self, state, action, reward, done, next_state):
        if self.size < self.max_size:
            self.state.append(state)
            self.action.append(action)
            self.reward.append(reward)
            self.done.append(done)
            self.next_state.append(next_state)
        else:
            idx = self.size % self.max_size
            self.state[idx] = state
            self.action[idx] = action
            self.reward[idx] = reward
            self.done[idx] = done
            self.next_state[idx] = next_state
        self.size += 1
        
    def sample(self, n):
        sample_num = min(self.size, self.max_size)
        indices = np.random.choice(range(sample_num), size=n, replace=True) if self.size < n else np.random.choice(range(sample_num), size=n, replace=False)
        state = torch.tensor([self.state[i] for i in indices], dtype=torch.float32, device=self.device)
        action = torch.tensor([self.action[i] for i in indices], dtype=torch.long, device=self.device)
        reward = torch.tensor([self.reward[i] for i in indices], dtype=torch.float32, device=self.device)
        done = torch.tensor([self.done[i] for i in indices], dtype=torch.float32, device=self.device)
        next_state = torch.tensor([self.next_state[i] for i in indices], dtype=torch.float32, device=self.device)
        return state, action, reward, done, next_state

# %%
# 训练
def train(args, env):
    agent = DuelingDQN(args.state_size, args.num_actions, args.discount, args.device)
    replay_buffer = ReplayBuffer(10000, args.device)
    optimizer = torch.optim.Adam(agent.Q.parameters(), lr=args.lr)
    writer = SummaryWriter()
    
    epsilon = 1
    epsilon_max = 1
    epsilon_min = 0.1
    
    episode_reward = 0
    episode_length = 0
    episode_num = 1
    max_episode_reward = -float('inf')
    
    agent.Q.train()
    state, _ = env.reset()
    
    for i in range(args.max_steps):
        if np.random.rand() < epsilon or i < args.warmup_steps:
            action = env.action_space.sample()
        else:
            action = agent.get_action(torch.from_numpy(state).to(args.device))
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        episode_reward += reward
        episode_length += 1
        replay_buffer.push(state, action, reward, done, next_state)
        state = next_state
        
        if done:
            if episode_reward > max_episode_reward:
                max_episode_reward = episode_reward
                save_path = os.path.join(args.output_dir, 'model.bin')
                torch.save(agent.Q.state_dict(), save_path)
                
            writer.add_scalar('Maximum reward', max_episode_reward, episode_num)
            writer.add_scalar('Episode reward', episode_reward, episode_num)
            writer.add_scalar('Episode length', episode_length, episode_num)
            print(f'step = {i}, reward = {episode_reward:.0f}, length = {episode_length}, max reward = {max_episode_reward}, epsilon = {epsilon:.3f}')
            
            episode_reward = 0
            episode_length = 0
            episode_num += 1
            epsilon = max(epsilon - (epsilon_max - epsilon_min) * args.epsilon_decay, epsilon_min)
            state, _ = env.reset()
            
        if i > args.warmup_steps:
            bs, ba, br, bd, bns = replay_buffer.sample(n=args.batch_size)
            loss = agent.compute_loss(bs, ba, br, bd, bns)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            agent.soft_update()
            if i % 500 == 0:
                writer.add_scalar('loss', loss.item(), i)
    
    writer.close()

# %%
# 测试
def eval(args, env):
    agent = DuelingDQN(args.state_size, args.num_actions, args.discount, args.device)
    model_path = os.path.join(args.output_dir, 'model.bin')
    agent.Q.load_state_dict(torch.load(model_path))
    agent.Q.to(args.device)
    agent.Q.eval()
    
    episode_reward = 0
    episode_length = 0
    state, _ = env.reset()
    for _ in range(5000):
        action = agent.get_action(torch.from_numpy(state).to(args.device))
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        episode_reward += reward
        episode_length += 1
        state = next_state
        
        if done:
            state, _ = env.reset()
            print(f'episode reward = {episode_reward:.0f}, episode_length = {episode_length}')
            episode_reward = 0
            episode_length = 0

# %%
# 运行
args = argparse.Namespace()
args.env = 'CartPole-v1'
args.state_size = 4
args.num_actions = 2
args.discount = 0.99
args.max_steps = int(1e5)
args.lr = 1e-3
args.batch_size = 32
args.warmup_steps = int(1e4)
args.output_dir = 'output'
args.epsilon_decay = 1 / 1000
if torch.backends.mps.is_available():
    args.device = torch.device('mps')
elif torch.cuda.is_available():
    args.device = torch.device('cuda')
else:
    args.device = torch.device('cpu')
    
os.makedirs(args.output_dir, exist_ok=True)
    
env = gym.make(args.env)
env.reset(seed=42)
env.action_space.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if args.device == torch.device('cuda'):
    torch.cuda.manual_seed(42)

print('Training started...')
train(args, env)
print('Training completed!')

print('Evaluation started...')
eval(args, env)
print('Evaluation completed!')
# Out:
# Training started...
# step = 28, reward = 29, length = 29, max reward = 29.0, epsilon = 1.000
# step = 45, reward = 17, length = 17, max reward = 29.0, epsilon = 0.999
# step = 114, reward = 69, length = 69, max reward = 69.0, epsilon = 0.998
# step = 129, reward = 15, length = 15, max reward = 69.0, epsilon = 0.997
# step = 168, reward = 39, length = 39, max reward = 69.0, epsilon = 0.996
# step = 193, reward = 25, length = 25, max reward = 69.0, epsilon = 0.995
# step = 207, reward = 14, length = 14, max reward = 69.0, epsilon = 0.995
# step = 230, reward = 23, length = 23, max reward = 69.0, epsilon = 0.994
# step = 258, reward = 28, length = 28, max reward = 69.0, epsilon = 0.993
# step = 300, reward = 42, length = 42, max reward = 69.0, epsilon = 0.992
# step = 325, reward = 25, length = 25, max reward = 69.0, epsilon = 0.991
# step = 353, reward = 28, length = 28, max reward = 69.0, epsilon = 0.990
# step = 370, reward = 17, length = 17, max reward = 69.0, epsilon = 0.989
# step = 403, reward = 33, length = 33, max reward = 69.0, epsilon = 0.988
# step = 415, reward = 12, length = 12, max reward = 69.0, epsilon = 0.987
# step = 432, reward = 17, length = 17, max reward = 69.0, epsilon = 0.986
# step = 448, reward = 16, length = 16, max reward = 69.0, epsilon = 0.986
# step = 470, reward = 22, length = 22, max reward = 69.0, epsilon = 0.985
# step = 22148, reward = 52, length = 52, max reward = 400.0, epsilon = 0.461
# step = 22311, reward = 163, length = 163, max reward = 400.0, epsilon = 0.460
# step = 22379, reward = 68, length = 68, max reward = 400.0, epsilon = 0.459
# step = 22573, reward = 194, length = 194, max reward = 400.0, epsilon = 0.458
# step = 22655, reward = 82, length = 82, max reward = 400.0, epsilon = 0.457
# step = 22892, reward = 237, length = 237, max reward = 400.0, epsilon = 0.456
# step = 23392, reward = 500, length = 500, max reward = 500.0, epsilon = 0.455
# step = 23441, reward = 49, length = 49, max reward = 500.0, epsilon = 0.455
# step = 23641, reward = 200, length = 200, max reward = 500.0, epsilon = 0.454
# step = 23765, reward = 124, length = 124, max reward = 500.0, epsilon = 0.453
# step = 23950, reward = 185, length = 185, max reward = 500.0, epsilon = 0.452
# step = 24119, reward = 169, length = 169, max reward = 500.0, epsilon = 0.451
# step = 24357, reward = 238, length = 238, max reward = 500.0, epsilon = 0.450
# step = 24462, reward = 105, length = 105, max reward = 500.0, epsilon = 0.449
# step = 24544, reward = 82, length = 82, max reward = 500.0, epsilon = 0.448
# step = 24569, reward = 25, length = 25, max reward = 500.0, epsilon = 0.447
# step = 24812, reward = 243, length = 243, max reward = 500.0, epsilon = 0.446
# step = 24851, reward = 39, length = 39, max reward = 500.0, epsilon = 0.446
# step = 25174, reward = 323, length = 323, max reward = 500.0, epsilon = 0.445
# step = 25352, reward = 178, length = 178, max reward = 500.0, epsilon = 0.444
# step = 25560, reward = 208, length = 208, max reward = 500.0, epsilon = 0.443
# step = 25635, reward = 75, length = 75, max reward = 500.0, epsilon = 0.442
# step = 25871, reward = 236, length = 236, max reward = 500.0, epsilon = 0.441
# step = 25970, reward = 99, length = 99, max reward = 500.0, epsilon = 0.440
# step = 26118, reward = 148, length = 148, max reward = 500.0, epsilon = 0.439
# step = 26211, reward = 93, length = 93, max reward = 500.0, epsilon = 0.438
# step = 26377, reward = 166, length = 166, max reward = 500.0, epsilon = 0.437
# step = 26393, reward = 16, length = 16, max reward = 500.0, epsilon = 0.437
# step = 26643, reward = 250, length = 250, max reward = 500.0, epsilon = 0.436
# step = 26667, reward = 24, length = 24, max reward = 500.0, epsilon = 0.435
# step = 26687, reward = 20, length = 20, max reward = 500.0, epsilon = 0.434
# step = 26881, reward = 194, length = 194, max reward = 500.0, epsilon = 0.433
# step = 27109, reward = 228, length = 228, max reward = 500.0, epsilon = 0.432
# step = 27147, reward = 38, length = 38, max reward = 500.0, epsilon = 0.431
# step = 27186, reward = 39, length = 39, max reward = 500.0, epsilon = 0.430
# step = 27217, reward = 31, length = 31, max reward = 500.0, epsilon = 0.429
# step = 27468, reward = 251, length = 251, max reward = 500.0, epsilon = 0.428
# step = 27714, reward = 246, length = 246, max reward = 500.0, epsilon = 0.428
# step = 27815, reward = 101, length = 101, max reward = 500.0, epsilon = 0.427
# ...
# step = 62152, reward = 20, length = 20, max reward = 500.0, epsilon = 0.241
# step = 62213, reward = 61, length = 61, max reward = 500.0, epsilon = 0.240
# step = 62258, reward = 45, length = 45, max reward = 500.0, epsilon = 0.239
# step = 62687, reward = 429, length = 429, max reward = 500.0, epsilon = 0.239
# step = 63110, reward = 423, length = 423, max reward = 500.0, epsilon = 0.238
# step = 63190, reward = 80, length = 80, max reward = 500.0, epsilon = 0.237
# step = 63580, reward = 390, length = 390, max reward = 500.0, epsilon = 0.236
# step = 63803, reward = 223, length = 223, max reward = 500.0, epsilon = 0.235
# step = 64247, reward = 444, length = 444, max reward = 500.0, epsilon = 0.234
# step = 64270, reward = 23, length = 23, max reward = 500.0, epsilon = 0.233
# step = 64736, reward = 466, length = 466, max reward = 500.0, epsilon = 0.232
# step = 65236, reward = 500, length = 500, max reward = 500.0, epsilon = 0.231
# step = 65251, reward = 15, length = 15, max reward = 500.0, epsilon = 0.230
# step = 65393, reward = 142, length = 142, max reward = 500.0, epsilon = 0.230
# step = 65893, reward = 500, length = 500, max reward = 500.0, epsilon = 0.229
# step = 66393, reward = 500, length = 500, max reward = 500.0, epsilon = 0.228
# step = 66725, reward = 332, length = 332, max reward = 500.0, epsilon = 0.227
# step = 66962, reward = 237, length = 237, max reward = 500.0, epsilon = 0.226
# step = 67148, reward = 186, length = 186, max reward = 500.0, epsilon = 0.225
# step = 67518, reward = 370, length = 370, max reward = 500.0, epsilon = 0.224
# step = 67822, reward = 304, length = 304, max reward = 500.0, epsilon = 0.223
# step = 68322, reward = 500, length = 500, max reward = 500.0, epsilon = 0.222
# step = 68621, reward = 299, length = 299, max reward = 500.0, epsilon = 0.221
# step = 68637, reward = 16, length = 16, max reward = 500.0, epsilon = 0.221
# step = 69137, reward = 500, length = 500, max reward = 500.0, epsilon = 0.220
# step = 69231, reward = 94, length = 94, max reward = 500.0, epsilon = 0.219
# step = 69245, reward = 14, length = 14, max reward = 500.0, epsilon = 0.218
# step = 69493, reward = 248, length = 248, max reward = 500.0, epsilon = 0.217
# step = 69855, reward = 362, length = 362, max reward = 500.0, epsilon = 0.216
# step = 70134, reward = 279, length = 279, max reward = 500.0, epsilon = 0.215
# step = 70220, reward = 86, length = 86, max reward = 500.0, epsilon = 0.214
# step = 70433, reward = 213, length = 213, max reward = 500.0, epsilon = 0.213
# step = 70832, reward = 399, length = 399, max reward = 500.0, epsilon = 0.212
# step = 71032, reward = 200, length = 200, max reward = 500.0, epsilon = 0.212
# step = 71295, reward = 263, length = 263, max reward = 500.0, epsilon = 0.211
# step = 71676, reward = 381, length = 381, max reward = 500.0, epsilon = 0.210
# step = 71767, reward = 91, length = 91, max reward = 500.0, epsilon = 0.209
# step = 71787, reward = 20, length = 20, max reward = 500.0, epsilon = 0.208
# step = 71867, reward = 80, length = 80, max reward = 500.0, epsilon = 0.207
# step = 71929, reward = 62, length = 62, max reward = 500.0, epsilon = 0.206
# step = 72046, reward = 117, length = 117, max reward = 500.0, epsilon = 0.205
# step = 72119, reward = 73, length = 73, max reward = 500.0, epsilon = 0.204
# step = 72191, reward = 72, length = 72, max reward = 500.0, epsilon = 0.203
# step = 72206, reward = 15, length = 15, max reward = 500.0, epsilon = 0.203
# step = 72706, reward = 500, length = 500, max reward = 500.0, epsilon = 0.202
# step = 72724, reward = 18, length = 18, max reward = 500.0, epsilon = 0.201
# step = 73038, reward = 314, length = 314, max reward = 500.0, epsilon = 0.200
# step = 73159, reward = 121, length = 121, max reward = 500.0, epsilon = 0.199
# step = 73325, reward = 166, length = 166, max reward = 500.0, epsilon = 0.198
# step = 73425, reward = 100, length = 100, max reward = 500.0, epsilon = 0.197
# step = 73439, reward = 14, length = 14, max reward = 500.0, epsilon = 0.196
# step = 73779, reward = 340, length = 340, max reward = 500.0, epsilon = 0.195
# step = 73840, reward = 61, length = 61, max reward = 500.0, epsilon = 0.194
# step = 73857, reward = 17, length = 17, max reward = 500.0, epsilon = 0.194
# step = 73948, reward = 91, length = 91, max reward = 500.0, epsilon = 0.193
# step = 73975, reward = 27, length = 27, max reward = 500.0, epsilon = 0.192
# step = 74163, reward = 188, length = 188, max reward = 500.0, epsilon = 0.191
# step = 74189, reward = 26, length = 26, max reward = 500.0, epsilon = 0.190
# step = 74397, reward = 208, length = 208, max reward = 500.0, epsilon = 0.189
# step = 74486, reward = 89, length = 89, max reward = 500.0, epsilon = 0.188
# step = 74574, reward = 88, length = 88, max reward = 500.0, epsilon = 0.187
# step = 74842, reward = 268, length = 268, max reward = 500.0, epsilon = 0.186
# step = 75202, reward = 360, length = 360, max reward = 500.0, epsilon = 0.185
# step = 75278, reward = 76, length = 76, max reward = 500.0, epsilon = 0.185
# step = 75394, reward = 116, length = 116, max reward = 500.0, epsilon = 0.184
# step = 75472, reward = 78, length = 78, max reward = 500.0, epsilon = 0.183
# step = 75627, reward = 155, length = 155, max reward = 500.0, epsilon = 0.182
# step = 75748, reward = 121, length = 121, max reward = 500.0, epsilon = 0.181
# step = 75851, reward = 103, length = 103, max reward = 500.0, epsilon = 0.180
# step = 76225, reward = 374, length = 374, max reward = 500.0, epsilon = 0.179
# step = 76344, reward = 119, length = 119, max reward = 500.0, epsilon = 0.178
# step = 76493, reward = 149, length = 149, max reward = 500.0, epsilon = 0.177
# step = 76594, reward = 101, length = 101, max reward = 500.0, epsilon = 0.176
# step = 76680, reward = 86, length = 86, max reward = 500.0, epsilon = 0.176
# step = 76701, reward = 21, length = 21, max reward = 500.0, epsilon = 0.175
# step = 76741, reward = 40, length = 40, max reward = 500.0, epsilon = 0.174
# step = 76827, reward = 86, length = 86, max reward = 500.0, epsilon = 0.173
# step = 76955, reward = 128, length = 128, max reward = 500.0, epsilon = 0.172
# step = 76972, reward = 17, length = 17, max reward = 500.0, epsilon = 0.171
# step = 77111, reward = 139, length = 139, max reward = 500.0, epsilon = 0.170
# step = 77283, reward = 172, length = 172, max reward = 500.0, epsilon = 0.169
# step = 77380, reward = 97, length = 97, max reward = 500.0, epsilon = 0.168
# step = 77578, reward = 198, length = 198, max reward = 500.0, epsilon = 0.167
# step = 77777, reward = 199, length = 199, max reward = 500.0, epsilon = 0.167
# step = 77924, reward = 147, length = 147, max reward = 500.0, epsilon = 0.166
# step = 78074, reward = 150, length = 150, max reward = 500.0, epsilon = 0.165
# step = 78087, reward = 13, length = 13, max reward = 500.0, epsilon = 0.164
# step = 78109, reward = 22, length = 22, max reward = 500.0, epsilon = 0.163
# step = 78240, reward = 131, length = 131, max reward = 500.0, epsilon = 0.162
# step = 78441, reward = 201, length = 201, max reward = 500.0, epsilon = 0.161
# step = 78600, reward = 159, length = 159, max reward = 500.0, epsilon = 0.160
# step = 78642, reward = 42, length = 42, max reward = 500.0, epsilon = 0.159
# step = 78672, reward = 30, length = 30, max reward = 500.0, epsilon = 0.158
# step = 78863, reward = 191, length = 191, max reward = 500.0, epsilon = 0.158
# step = 78875, reward = 12, length = 12, max reward = 500.0, epsilon = 0.157
# step = 79005, reward = 130, length = 130, max reward = 500.0, epsilon = 0.156
# step = 79187, reward = 182, length = 182, max reward = 500.0, epsilon = 0.155
# step = 79356, reward = 169, length = 169, max reward = 500.0, epsilon = 0.154
# step = 79366, reward = 10, length = 10, max reward = 500.0, epsilon = 0.153
# step = 79524, reward = 158, length = 158, max reward = 500.0, epsilon = 0.152
# step = 79672, reward = 148, length = 148, max reward = 500.0, epsilon = 0.151
# step = 79832, reward = 160, length = 160, max reward = 500.0, epsilon = 0.150
# step = 79992, reward = 160, length = 160, max reward = 500.0, epsilon = 0.149
# step = 80133, reward = 141, length = 141, max reward = 500.0, epsilon = 0.149
# step = 80386, reward = 253, length = 253, max reward = 500.0, epsilon = 0.148
# step = 80489, reward = 103, length = 103, max reward = 500.0, epsilon = 0.147
# step = 80696, reward = 207, length = 207, max reward = 500.0, epsilon = 0.146
# step = 81052, reward = 356, length = 356, max reward = 500.0, epsilon = 0.145
# step = 81458, reward = 406, length = 406, max reward = 500.0, epsilon = 0.144
# step = 81718, reward = 260, length = 260, max reward = 500.0, epsilon = 0.143
# step = 81900, reward = 182, length = 182, max reward = 500.0, epsilon = 0.142
# step = 82400, reward = 500, length = 500, max reward = 500.0, epsilon = 0.141
# step = 82454, reward = 54, length = 54, max reward = 500.0, epsilon = 0.140
# step = 82954, reward = 500, length = 500, max reward = 500.0, epsilon = 0.140
# step = 82990, reward = 36, length = 36, max reward = 500.0, epsilon = 0.139
# step = 83000, reward = 10, length = 10, max reward = 500.0, epsilon = 0.138
# step = 83093, reward = 93, length = 93, max reward = 500.0, epsilon = 0.137
# step = 83242, reward = 149, length = 149, max reward = 500.0, epsilon = 0.136
# step = 83398, reward = 156, length = 156, max reward = 500.0, epsilon = 0.135
# step = 83542, reward = 144, length = 144, max reward = 500.0, epsilon = 0.134
# step = 83714, reward = 172, length = 172, max reward = 500.0, epsilon = 0.133
# step = 83858, reward = 144, length = 144, max reward = 500.0, epsilon = 0.132
# step = 83996, reward = 138, length = 138, max reward = 500.0, epsilon = 0.131
# step = 84166, reward = 170, length = 170, max reward = 500.0, epsilon = 0.131
# step = 84302, reward = 136, length = 136, max reward = 500.0, epsilon = 0.130
# step = 84426, reward = 124, length = 124, max reward = 500.0, epsilon = 0.129
# step = 84562, reward = 136, length = 136, max reward = 500.0, epsilon = 0.128
# step = 84692, reward = 130, length = 130, max reward = 500.0, epsilon = 0.127
# step = 84831, reward = 139, length = 139, max reward = 500.0, epsilon = 0.126
# step = 84970, reward = 139, length = 139, max reward = 500.0, epsilon = 0.125
# step = 85107, reward = 137, length = 137, max reward = 500.0, epsilon = 0.124
# step = 85250, reward = 143, length = 143, max reward = 500.0, epsilon = 0.123
# step = 85387, reward = 137, length = 137, max reward = 500.0, epsilon = 0.122
# step = 85521, reward = 134, length = 134, max reward = 500.0, epsilon = 0.122
# step = 85555, reward = 34, length = 34, max reward = 500.0, epsilon = 0.121
# step = 85708, reward = 153, length = 153, max reward = 500.0, epsilon = 0.120
# step = 85738, reward = 30, length = 30, max reward = 500.0, epsilon = 0.119
# step = 85881, reward = 143, length = 143, max reward = 500.0, epsilon = 0.118
# step = 86051, reward = 170, length = 170, max reward = 500.0, epsilon = 0.117
# step = 86193, reward = 142, length = 142, max reward = 500.0, epsilon = 0.116
# step = 86403, reward = 210, length = 210, max reward = 500.0, epsilon = 0.115
# step = 86562, reward = 159, length = 159, max reward = 500.0, epsilon = 0.114
# step = 86711, reward = 149, length = 149, max reward = 500.0, epsilon = 0.113
# step = 86864, reward = 153, length = 153, max reward = 500.0, epsilon = 0.113
# step = 87007, reward = 143, length = 143, max reward = 500.0, epsilon = 0.112
# step = 87199, reward = 192, length = 192, max reward = 500.0, epsilon = 0.111
# step = 87699, reward = 500, length = 500, max reward = 500.0, epsilon = 0.110
# step = 88199, reward = 500, length = 500, max reward = 500.0, epsilon = 0.109
# step = 88303, reward = 104, length = 104, max reward = 500.0, epsilon = 0.108
# step = 88384, reward = 81, length = 81, max reward = 500.0, epsilon = 0.107
# step = 88877, reward = 493, length = 493, max reward = 500.0, epsilon = 0.106
# step = 89377, reward = 500, length = 500, max reward = 500.0, epsilon = 0.105
# step = 89877, reward = 500, length = 500, max reward = 500.0, epsilon = 0.104
# step = 90118, reward = 241, length = 241, max reward = 500.0, epsilon = 0.104
# step = 90584, reward = 466, length = 466, max reward = 500.0, epsilon = 0.103
# step = 91084, reward = 500, length = 500, max reward = 500.0, epsilon = 0.102
# step = 91280, reward = 196, length = 196, max reward = 500.0, epsilon = 0.101
# step = 91602, reward = 322, length = 322, max reward = 500.0, epsilon = 0.100
# step = 91738, reward = 136, length = 136, max reward = 500.0, epsilon = 0.100
# step = 91870, reward = 132, length = 132, max reward = 500.0, epsilon = 0.100
# step = 91986, reward = 116, length = 116, max reward = 500.0, epsilon = 0.100
# step = 92311, reward = 325, length = 325, max reward = 500.0, epsilon = 0.100
# step = 92327, reward = 16, length = 16, max reward = 500.0, epsilon = 0.100
# step = 92827, reward = 500, length = 500, max reward = 500.0, epsilon = 0.100
# step = 93185, reward = 358, length = 358, max reward = 500.0, epsilon = 0.100
# step = 93200, reward = 15, length = 15, max reward = 500.0, epsilon = 0.100
# step = 93536, reward = 336, length = 336, max reward = 500.0, epsilon = 0.100
# step = 93692, reward = 156, length = 156, max reward = 500.0, epsilon = 0.100
# step = 93907, reward = 215, length = 215, max reward = 500.0, epsilon = 0.100
# step = 94276, reward = 369, length = 369, max reward = 500.0, epsilon = 0.100
# step = 94438, reward = 162, length = 162, max reward = 500.0, epsilon = 0.100
# step = 94894, reward = 456, length = 456, max reward = 500.0, epsilon = 0.100
# step = 94953, reward = 59, length = 59, max reward = 500.0, epsilon = 0.100
# step = 95065, reward = 112, length = 112, max reward = 500.0, epsilon = 0.100
# step = 95201, reward = 136, length = 136, max reward = 500.0, epsilon = 0.100
# step = 95341, reward = 140, length = 140, max reward = 500.0, epsilon = 0.100
# step = 95398, reward = 57, length = 57, max reward = 500.0, epsilon = 0.100
# step = 95518, reward = 120, length = 120, max reward = 500.0, epsilon = 0.100
# step = 95938, reward = 420, length = 420, max reward = 500.0, epsilon = 0.100
# step = 96078, reward = 140, length = 140, max reward = 500.0, epsilon = 0.100
# step = 96196, reward = 118, length = 118, max reward = 500.0, epsilon = 0.100
# step = 96696, reward = 500, length = 500, max reward = 500.0, epsilon = 0.100
# step = 96849, reward = 153, length = 153, max reward = 500.0, epsilon = 0.100
# step = 96861, reward = 12, length = 12, max reward = 500.0, epsilon = 0.100
# step = 97114, reward = 253, length = 253, max reward = 500.0, epsilon = 0.100
# step = 97326, reward = 212, length = 212, max reward = 500.0, epsilon = 0.100
# step = 97826, reward = 500, length = 500, max reward = 500.0, epsilon = 0.100
# step = 97961, reward = 135, length = 135, max reward = 500.0, epsilon = 0.100
# step = 98061, reward = 100, length = 100, max reward = 500.0, epsilon = 0.100
# step = 98074, reward = 13, length = 13, max reward = 500.0, epsilon = 0.100
# step = 98252, reward = 178, length = 178, max reward = 500.0, epsilon = 0.100
# step = 98681, reward = 429, length = 429, max reward = 500.0, epsilon = 0.100
# step = 99001, reward = 320, length = 320, max reward = 500.0, epsilon = 0.100
# step = 99140, reward = 139, length = 139, max reward = 500.0, epsilon = 0.100
# step = 99460, reward = 320, length = 320, max reward = 500.0, epsilon = 0.100
# step = 99643, reward = 183, length = 183, max reward = 500.0, epsilon = 0.100
# step = 99706, reward = 63, length = 63, max reward = 500.0, epsilon = 0.100
# step = 99787, reward = 81, length = 81, max reward = 500.0, epsilon = 0.100
# Training completed!
# Evaluation started...
# episode reward = 297, episode_length = 297
# episode reward = 295, episode_length = 295
# episode reward = 334, episode_length = 334
# episode reward = 357, episode_length = 357
# episode reward = 259, episode_length = 259
# episode reward = 365, episode_length = 365
# episode reward = 278, episode_length = 278
# episode reward = 307, episode_length = 307
# episode reward = 394, episode_length = 394
# episode reward = 386, episode_length = 386
# episode reward = 494, episode_length = 494
# episode reward = 313, episode_length = 313
# episode reward = 259, episode_length = 259
# episode reward = 416, episode_length = 416
# Evaluation completed!

# %% [markdown]
# #### Reward:
#
# ![fig1](https://raw.githubusercontent.com/Xavier-MaYiMing/Reinforcement-learning-and-combinatorial-optimzation/main/figs/Dueling%20DQN%20-%20reward.png)
#
# #### Maximum reward:
#
# ![fig2](https://raw.githubusercontent.com/Xavier-MaYiMing/Reinforcement-learning-and-combinatorial-optimzation/main/figs/Dueling%20DQN%20-%20max%20reward.png)
