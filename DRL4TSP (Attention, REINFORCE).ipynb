# %% [markdown]
# # 1. 自注意力 (self attention)
#
# 给定查询$\mathbf{q} \in \mathbb{R}^{d_q}$、键$\mathbf{k} \in \mathbb{R}^{d_k}$和值$\mathbf{v} \in \mathbb{R}^{d_v}$，每个注意力头$h_i (i = 1, \cdots, h)$的计算方法为:
#
# $$
# h_i = f(\mathbf{W}_i^{(q)}q, \mathbf{W}_i^{(k)}k, \mathbf{W}_i^{(v)}v) \in \mathbb{R}^{p_v}
# $$
#
# 其中可学习的参数为$\mathbf{W}_i^{(q)} \in \mathbb{R}^{p_v \times d_q}, \mathbf{W}_i^{(k)} \in \mathbb{R}^{p_k \times d_k}, \mathbf{W}_i^{(v)} \in \mathbb{R}^{p_v \times d_v}$。$f$代表注意力汇聚函数，例如加性注意力或点积注意力。多头注意力的输出需要另外的线性变化，可学习的参数为$\mathbf{W}_o \in \mathbb{R}^{p_o \times hp_v}$:
#
# $$
# W_o [h_1, \cdots, h_h]^{\text{T}} \in \mathbb{R}^{p_o}
# $$
#
# 给定长度为$n$的输入序列$x_1, \cdots, x_n, x_i \in \mathbb{R}^d$，自注意力输出一个长度相同的输出序列$y_1, \cdots, y_n$，其中:
#
# $$
# y_i = f(x_i, (x_1, x_1), \cdots, (x_n, y_n)) \in \mathbb{R}^d
# $$
#
# # 2. 残差块
#
# 假设原始输入为$x$，希望学出的理想映射为$f(x)$，下图左边需要直接拟合$f(x)$，右图需要拟合残差映射$f(x) - x$。残差映射在现实中更容易优化，也易于捕捉恒等映射的细微波动。在残差块中，输入可通过跨层数据线路更快地向前传播。
#
# ![image.png](attachment:image.png)
#
# # 3. 批量规范化 (batch normalization)
#
# 结合残差块和批量规范化，可以训练100层以上的网络。每次训练中，现规范化输入，减去均值并处以标准差，然后应用比例系数和比例偏移。用$x \in \mathcal{B}$来表示一个来自小批量$\mathcal{B}$的输入，则表达式如下:
#
# $$
# BN(x) = \gamma \odot \frac{x - \hat{\mu}_\mathcal{B}}{\hat{\sigma}_\mathcal{B}} + \beta
# $$
#
# $\gamma$和$\beta$是要与其他模型参数一起学习的参数。
#
# $$
# \begin{aligned}
#     & \hat{\mu}_\mathcal{B} = \frac{1}{\mid \mathcal{B} \mid} \sum_{x \in \mathcal{B}} x\\
#     & \hat{\sigma}^2_\mathcal{B} = \frac{1}{\mid \mathcal{B} \mid} \sum_{x \in \mathcal{B}} (x - \hat{\sigma}_\mathcal{B})^2 + \epsilon
# \end{aligned}
# $$
#
# 在训练过程中，无法得知整个数据集的平均值和方差，所以只能根据每个小批次的均值和方差不断训练模型。在预测过程中，可以得知整个数据集的平均值和方差，或做逐样本预测时，通过移动平均估算整个训练数据集的样本均值和方差。

# %%
# 导入库
import os
import math
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter

# %%
# 定义TSPDataset类
class TSPDataset(Dataset):
    def __init__(self, num_nodes, num_samples, random_seed=42):
        super().__init__()
        
        self.num_nodes = num_nodes
        self.num_samples = num_samples
        self.random_seed = random_seed

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        seed = self.random_seed + idx
        generator = torch.Generator()
        generator.manual_seed(seed)
        sample = torch.rand(self.num_nodes, 2, generator=generator)
        return sample

# %%
# 定义reward函数
def reward(sols):
    # sols: (batch_size, seq_len, input_size)
    # lengths: (batch_size,)
    lengths = torch.norm(sols[:, 1:, :] - sols[:, :-1, :], dim=2).sum(dim=1)
    lengths += torch.norm(sols[:, -1, :] - sols[:, 0, :], dim=1)
    return lengths

# %%
# 定义ResidualConnection
class ResidualConnection(nn.Module):
    def __init__(self, module):
        super().__init__()
        
        self.module = module
        
    def forward(self, x):
        return x + self.module(x)

# %%
# 定义Normalization类
class Normalization(nn.Module):
    def __init__(self, embedding_size, normalization='batch'):
        super().__init__()
        
        normalizer = {
            'batch': nn.BatchNorm1d,
            'instance': nn.InstanceNorm1d,
        }.get(normalization, None)
        assert normalizer is not None, f'Unsupported normalization type: {normalization}'
        
        self.normalizer = normalizer(embedding_size, affine=True)
        
        self._init_parameters()
        
    def _init_parameters(self):
        if hasattr(self.normalizer, 'weight') and self.normalizer.weight is not None:
            nn.init.uniform_(self.normalizer.weight, 0., 1.)
        if hasattr(self.normalizer, 'bias') and self.normalizer.bias is not None:
            nn.init.zeros_(self.normalizer.bias)
            
    def forward(self, x):
        if isinstance(self.normalizer, nn.BatchNorm1d):
            return self.normalizer(x.view(-1, x.size(-1))).view(*x.size())
        else:
            return self.normalizer(x.permute(0, 2, 1)).permute(0, 2, 1)

# %%
# 定义MultiHeadAttention类
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, query_size, key_size, value_size, embedding_size, dropout=0.1):
        super().__init__()
        assert embedding_size % num_heads == 0
    
        self.num_heads = num_heads
        self.embedding_size = embedding_size
        self.head_size = embedding_size // num_heads
        
        self.W_q = nn.Linear(query_size, embedding_size)
        self.W_k = nn.Linear(key_size, embedding_size)
        self.W_v = nn.Linear(value_size, embedding_size)
        self.W_o = nn.Linear(embedding_size, embedding_size)
        
        self.scale_factor = math.sqrt(self.head_size)
        self.dropout = nn.Dropout(dropout)
        
        self._init_parameters()
        
    def _init_parameters(self):
        for param in self.parameters():
            std = 1. / math.sqrt(param.size(-1))
            param.data.uniform_(-std, std)
            
    def forward(self, q, k=None, v=None, mask=None):
        # q: (batch_size, q_len, query_size)
        # k: (batch_size, seq_len, key_size)
        # v: (batch_size, seq_len, value_size)
        # mask: (batch_size, seq_len)
        if k is None:
            k = q
            v = q
        batch_size, q_len, _ = q.size()
        seq_len = k.size(1)
        
        # Q: (batch_size, q_len, embedding_size)
        Q = self.W_q(q)
        # K, V: (batch_size, seq_len, embedding_size)
        K = self.W_k(k)
        V = self.W_v(v)
        
        # Q: (batch_size, num_heads, q_len, head_size)
        Q = Q.view(batch_size, q_len, self.num_heads, self.head_size).transpose(1, 2)
        # K, V: (batch_size, num_heads, seq_len, head_size)
        K = K.view(batch_size, seq_len, self.num_heads, self.head_size).transpose(1, 2)
        V = V.view(batch_size, seq_len, self.num_heads, self.head_size).transpose(1, 2)
        
        # attn_scores: (batch_size, num_heads, q_len, seq_len)
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / self.scale_factor
        if mask is not None:
            # mask: (batch_size, num_heads, q_len, seq_len)
            mask = mask.unsqueeze(1).unsqueeze(1).expand(-1, self.num_heads, q_len, -1)
            mask_clone = mask.clone().bool()
            attn_scores = attn_scores.masked_fill(mask_clone, float('-inf'))
            
        # attn_weights: (batch_size, num_heads, q_len, seq_len)
        attn_weights = F.softmax(attn_scores, -1)
        attn_weights = self.dropout(attn_weights)
        
        # attn_output: (batch_size, num_heads, q_len, head_size)
        attn_output = torch.matmul(attn_weights, V)
        # attn_output: (batch_size, q_len, embedding_size)
        attn_output = attn_output.transpose(1, 2).contiguous().view(batch_size, q_len, self.embedding_size)
        
        # output: (batch_size, q_len, embedding_size)
        output = self.W_o(attn_output)
        
        return output

# %%
# 定义MultiHeadAttentionLayer类
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, num_heads, embedding_size, FF_hidden_size=512, normalization='batch', dropout=0.1):
        super().__init__()
        
        self.attention = ResidualConnection(MultiHeadAttention(num_heads, embedding_size, embedding_size, embedding_size, embedding_size, dropout))
        self.norm1 = Normalization(embedding_size, normalization)
        
        self.feed_forward = ResidualConnection(
            nn.Sequential(
                nn.Linear(embedding_size, FF_hidden_size),
                nn.ReLU(),
                nn.Dropout(dropout),
                nn.Linear(FF_hidden_size, embedding_size),
            ) if FF_hidden_size > 0 else nn.Linear(embedding_size, embedding_size)
        )
        self.norm2 = Normalization(embedding_size, normalization)
        
    def forward(self, x):
        x = self.norm1(self.attention(x))
        x = self.norm2(self.feed_forward(x))
        return x

# %%
# 定义Encoder类
class Encoder(nn.Module):
    def __init__(self, num_heads, embedding_size, num_layers, input_size=None, FF_hidden_size=512, normalization='batch', dropout=0.1):
        super().__init__()
        
        self.embedding = nn.Linear(input_size, embedding_size) if input_size is not None else None
        self.layers = nn.Sequential(*(
            MultiHeadAttentionLayer(num_heads, embedding_size, FF_hidden_size, normalization, dropout)
            for _ in range(num_layers)
        ))
        
    def forward(self, inputs):
        # inputs: (batch_size, seq_len, input_size)
        if self.embedding is not None:
            # embedded: (batch_size, seq_len, embedding_size)
            embedded = self.embedding(inputs)
        # node_embedding: (batch_size, seq_len, embedding_size)
        node_embedding = self.layers(embedded)
        return node_embedding

# %% [markdown]
# ![210902bf55e7c59bdecdb6d128a8b74d.png](attachment:210902bf55e7c59bdecdb6d128a8b74d.png)

# %%
# 定义Decoder类
class Decoder(nn.Module):
    def __init__(self, num_heads, embedding_size, C=10, dropout=0.1, temperature=None):
        super().__init__()
        assert embedding_size % num_heads == 0
        
        self.num_heads = num_heads
        self.embedding_size = embedding_size
        self.C = C
        self.temperature = temperature
        
        self.input_placeholder = nn.Parameter(torch.zeros(2 * embedding_size))

        self.multihead_attention = MultiHeadAttention(num_heads, 3 * embedding_size, embedding_size, embedding_size, embedding_size, dropout)
        
        self.W_q = nn.Linear(embedding_size, embedding_size)
        self.W_k = nn.Linear(embedding_size, embedding_size)
        self.scale_factor = math.sqrt(embedding_size)
        
        self._init_parameters()
        
    def _init_parameters(self):
        for param in self.parameters():
            std = 1. / math.sqrt(param.size(-1))
            param.data.uniform_(-std, std)
            
    def forward(self, node_embedding):
        # node_embedding: (batch_size, seq_len, embedding_size)
        batch_size, seq_len, embedding_size = node_embedding.size()
        assert self.embedding_size == embedding_size
        
        # graph_embedding: (batch_size, embedding_size)
        graph_embedding = node_embedding.mean(dim=1)
        
        # mask: (batch_size, seq_len)
        mask = torch.zeros(batch_size, seq_len, dtype=torch.bool, device=node_embedding.device)
        
        idxs = None
        first_node_context, current_node_context = None, None
        prev_probs, prev_idxs = [], []
        
        for _ in range(seq_len):
            if first_node_context is None:
                # context_embedding: (batch_size, 3 * embedding_size)
                context_embedding = torch.cat((graph_embedding, self.input_placeholder.unsqueeze(0).expand(batch_size, -1)), dim=1)
            else:
                # context_embedding: (batch_size, 3 * embedding_size)
                context_embedding = torch.cat((graph_embedding, current_node_context, first_node_context), dim=1)
                
            # attn_output: (batch_size, embedding_size)
            attn_output = self.multihead_attention(context_embedding.unsqueeze(1), node_embedding, node_embedding, mask).squeeze(1)
            
            # query: (batch_size, embedding_size)
            query = self.W_q(attn_output)
            # key: (batch_size, seq_len, embedding_size)
            key = self.W_k(node_embedding)
            
            # logits: (batch_size, seq_len)
            logits = torch.matmul(query.unsqueeze(1), key.transpose(-2, -1)).squeeze(1) / self.scale_factor
            logits = self.C * torch.tanh(logits)
            mask_clone = mask.clone().bool()
            logits = logits.masked_fill(mask_clone, float('-inf'))
            
            # probs: (batch_size, seq_len)
            probs = F.softmax(logits, dim=-1) if self.temperature is None else F.softmax(logits / self.temperature, dim=-1)
            # idxs: (batch_size,)
            idxs = torch.multinomial(probs, 1).squeeze(1)
            mask[torch.arange(batch_size), idxs] = True
            
            prev_probs.append(probs[torch.arange(batch_size), idxs])
            prev_idxs.append(idxs)
            
            # current_node_context: (batch_size, embedding_size)
            current_node_context = node_embedding[torch.arange(batch_size), idxs, :]
            if first_node_context is None:
                first_node_context = current_node_context
        
        # prev_probs, prev_idxs: (batch_size, seq_len)
        prev_probs = torch.stack(prev_probs, dim=1)
        prev_idxs = torch.stack(prev_idxs, dim=1)
        return prev_probs, prev_idxs

# %% [markdown]
# ![580336bf72a573cf3aacaddf1390f99b.png](attachment:580336bf72a573cf3aacaddf1390f99b.png)

# %%
# 定义Actor类
class Actor(nn.Module):
    def __init__(self, num_heads, embedding_size, num_layers, input_size, FF_hidden_size, normalization, dropout, C, temperature, reward):
        super().__init__()
        
        self.reward = reward
        
        self.encoder = Encoder(num_heads, embedding_size, num_layers, input_size, FF_hidden_size, normalization, dropout)
        self.decoder = Decoder(num_heads, embedding_size, C, dropout)
    
    def forward(self, inputs):
        # inputs: (batch_size, seq_len, input_size)
        # node_embedding: (batch_size, seq_len, embedding_size)
        node_embedding = self.encoder(inputs)
        # probs, idxs: (batch_size, seq_len)
        probs, idxs = self.decoder(node_embedding)
        # actions: (batch_size, seq_len, input_size)
        actions = inputs[torch.arange(inputs.size(0)).unsqueeze(1), idxs]
        # rewards: (batch_size,)
        rewards = self.reward(actions)
        return rewards, idxs, probs

# %%
# 训练
def train(args, train_dataset, val_dataset):
    train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=args.batch_size, shuffle=False)
    
    actor = Actor(args.num_heads, args.embedding_size, args.num_layers, args.input_size, args.FF_hidden_size, args.normalization, args.dropout, args.C, args.temperature, reward).to(args.device)
    optimizer = optim.Adam(actor.parameters(), lr=args.lr)
    
    step = 0
    baseline = 0
    best_length = float('inf')
    train_lengths, val_lengths = [], []
    writer = SummaryWriter()
    model_path = os.path.join(args.output_dir, args.name)
    
    for epoch in range(args.n_epochs):
        for batch_id, train_batch in enumerate(train_loader):
            actor.train()
            
            # inputs: (batch_size, seq_len, input_size)
            inputs = train_batch.to(args.device)
            # rewards: (batch_size,)
            # probs, idxs: (batch_size, seq_len)
            rewards, idxs, probs = actor(inputs)
            # log_probs: (batch_size,)
            log_probs = torch.log(probs.clamp(min=1e-10)).sum(dim=1)
            log_probs = torch.clamp(log_probs, min=-100)
            baseline = args.beta * baseline + (1 - args.beta) * rewards.mean().item()
            # advantage: (batch_size,)
            advantage = rewards - baseline
            # reinforce: (batch_size)
            reinforce = advantage.detach() * log_probs
            actor_loss = reinforce.mean()
            
            optimizer.zero_grad()
            actor_loss.backward()
            torch.nn.utils.clip_grad_norm_(actor.parameters(), args.max_grad_norm)
            optimizer.step()
            
            writer.add_scalar('Actor_Loss/train', actor_loss.item(), step)
            writer.add_scalar('Length/train', rewards.mean().item(), step)       
            step += 1
            
            if batch_id % 100 == 0:
                print(f"Epoch [{epoch + 1}/{args.n_epochs}], Batch [{batch_id + 1}/{len(train_loader)}], "
                      f"Actor Loss: {actor_loss.item():.4f}, Reward: {rewards.mean().item():.4f}")
                actor.eval()
                with torch.no_grad():
                    total_rewards, total_nums = 0, 0
                    for val_batch in val_loader:
                        inputs = val_batch.to(args.device)
                        rewards, _, _ = actor(inputs)
                        total_rewards += rewards.sum().item()
                        total_nums += inputs.size(0)
                    avg_reward = total_rewards / total_nums
                    writer.add_scalar('Length/validation', avg_reward, step)
                    print(f"Validation average reward after epoch {epoch + 1}: {avg_reward:.4f}")
                    
                    if avg_reward < best_length:
                        best_length = avg_reward
                        torch.save(actor.state_dict(), model_path)
                        
    writer.close()

# %%
# 画TSP示例图
def plot_tsp_paths(args, inputs, idxs, rewards):
    # inputs: (batch_size, seq_len, 2)
    # idxs: (batch_size, seq_len)
    # rewards: (batch_size,)
    inputs = inputs.cpu().numpy()
    idxs = idxs.cpu().numpy()
    rewards = rewards.cpu().numpy()
    
    fig, axes = plt.subplots(2, 4, figsize=(16, 8))
    fig.suptitle(args.name)
    
    for i in range(8):
        ax = axes[i // 4, i % 4]
        coords = inputs[i]
        path = idxs[i]
        
        for j in range(len(path)):
            x1, y1 = coords[path[j - 1]]
            x2, y2 = coords[path[j]]
            ax.plot([x1, x2], [y1, y2], 'bo-')
        
        ax.scatter(coords[:, 0], coords[:, 1], c='red')
        ax.scatter(coords[0, 0], coords[0, 1], c='yellow')
        ax.set_title(f'Length: {rewards[i]:.3f}')
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

# %%
# 测试 (greedy)
def test1(args, test_dataset):
    test_loader = DataLoader(test_dataset, batch_size=args.batch_size, shuffle=False)
    
    actor = Actor(args.num_heads, args.embedding_size, args.num_layers, args.input_size, args.FF_hidden_size, args.normalization, args.dropout, args.C, args.temperature, reward).to(args.device)
    actor.load_state_dict(torch.load(os.path.join(args.output_dir, args.name)))
    
    actor.eval()
    total_rewards, total_nums = 0, 0
    
    with torch.no_grad():
        for i, test_batch in enumerate(test_loader):
            inputs = test_batch.to(args.device)
            rewards, idxs, _ = actor(inputs)
            total_rewards += rewards.sum().item()
            total_nums += inputs.size(0)
            
            if i == 0 and inputs.size(0) >= 8:
                plot_tsp_paths(args, inputs[:8], idxs[:8], rewards[:8])
            
    avg_reward = total_rewards / total_nums
    print(f"Test average reward: {avg_reward:.4f}")

# %%
args = argparse.Namespace()
args.seq_len = 20
args.n_epochs = 100
args.batch_size = 512
args.lr = 1e-4
args.num_heads = 8
args.embedding_size = 128
args.num_layers = 3
args.input_size = 2
args.FF_hidden_size = 512
args.normalization = 'batch'
args.dropout = 0.1
args.C = 10 
args.temperature = None
args.beta = 0.99
args.max_grad_norm = 1.
args.num_samples = 1280
args.output_dir = 'output'
args.name = 'DRL4TSP_Attention_REINFORCE_TSP' + str(args.seq_len)
args.device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

os.makedirs(args.output_dir, exist_ok=True)

train_dataset = TSPDataset(args.seq_len, 1280000)
val_dataset = TSPDataset(args.seq_len, 1280)
test_dataset = TSPDataset(args.seq_len, 1280)

# %%
print('Training started...')
train(args, train_dataset, val_dataset)
print('Training completed!')
# Out:
# Training started...
# Epoch [1/100], Batch [1/2500], Actor Loss: -430.7061, Reward: 10.3410
# Validation average reward after epoch 1: 10.4480
# Epoch [1/100], Batch [101/2500], Actor Loss: -10.2541, Reward: 5.3352
# Validation average reward after epoch 1: 5.2685
# Epoch [1/100], Batch [201/2500], Actor Loss: 0.8677, Reward: 4.6319
# Validation average reward after epoch 1: 4.5795
# Epoch [1/100], Batch [301/2500], Actor Loss: 0.6753, Reward: 4.4710
# Validation average reward after epoch 1: 4.3960
# Epoch [1/100], Batch [401/2500], Actor Loss: 0.3156, Reward: 4.3719
# Validation average reward after epoch 1: 4.3127
# Epoch [1/100], Batch [501/2500], Actor Loss: 0.4779, Reward: 4.2711
# Validation average reward after epoch 1: 4.2630
# Epoch [1/100], Batch [601/2500], Actor Loss: 0.2092, Reward: 4.2251
# Validation average reward after epoch 1: 4.1641
# Epoch [1/100], Batch [701/2500], Actor Loss: -0.0181, Reward: 4.1876
# Validation average reward after epoch 1: 4.1275
# Epoch [1/100], Batch [801/2500], Actor Loss: -0.2281, Reward: 4.1805
# Validation average reward after epoch 1: 4.1207
# Epoch [1/100], Batch [901/2500], Actor Loss: -0.0281, Reward: 4.1355
# Validation average reward after epoch 1: 4.1010
# Epoch [1/100], Batch [1001/2500], Actor Loss: 0.0036, Reward: 4.0815
# Validation average reward after epoch 1: 4.0719
# Epoch [1/100], Batch [1101/2500], Actor Loss: -0.2241, Reward: 4.1358
# Validation average reward after epoch 1: 4.0692
# Epoch [1/100], Batch [1201/2500], Actor Loss: -0.0751, Reward: 4.0865
# Validation average reward after epoch 1: 4.0562
# Epoch [1/100], Batch [1301/2500], Actor Loss: -0.2541, Reward: 4.1027
# Validation average reward after epoch 1: 4.0531
# Epoch [1/100], Batch [1401/2500], Actor Loss: -0.1784, Reward: 4.1025
# Validation average reward after epoch 1: 4.0509
# Epoch [1/100], Batch [1501/2500], Actor Loss: -0.0478, Reward: 4.0638
# Validation average reward after epoch 1: 4.0426
# Epoch [1/100], Batch [1601/2500], Actor Loss: -0.2536, Reward: 4.1079
# Validation average reward after epoch 1: 4.0317
# Epoch [1/100], Batch [1701/2500], Actor Loss: -0.1351, Reward: 4.0655
# Validation average reward after epoch 1: 4.0389
# Epoch [1/100], Batch [1801/2500], Actor Loss: -0.2259, Reward: 4.0925
# Validation average reward after epoch 1: 4.0540
# Epoch [1/100], Batch [1901/2500], Actor Loss: -0.1806, Reward: 4.0760
# Validation average reward after epoch 1: 4.0201
# Epoch [1/100], Batch [2001/2500], Actor Loss: -0.1305, Reward: 4.0529
# Validation average reward after epoch 1: 4.0212
# Epoch [1/100], Batch [2101/2500], Actor Loss: -0.2559, Reward: 4.0834
# Validation average reward after epoch 1: 4.0321
# Epoch [1/100], Batch [2201/2500], Actor Loss: -0.1233, Reward: 4.0598
# Validation average reward after epoch 1: 4.0182
# Epoch [1/100], Batch [2301/2500], Actor Loss: -0.0321, Reward: 4.0127
# Validation average reward after epoch 1: 4.0077
# Epoch [1/100], Batch [2401/2500], Actor Loss: -0.3096, Reward: 4.0774
# Validation average reward after epoch 1: 4.0409
# Epoch [2/100], Batch [1/2500], Actor Loss: -0.1101, Reward: 4.0534
# Validation average reward after epoch 2: 4.0202
# Epoch [2/100], Batch [101/2500], Actor Loss: -0.0829, Reward: 4.0280
# Validation average reward after epoch 2: 4.0015
# Epoch [2/100], Batch [201/2500], Actor Loss: -0.1829, Reward: 4.0374
# Validation average reward after epoch 2: 3.9989
# Epoch [2/100], Batch [301/2500], Actor Loss: -0.1131, Reward: 4.0471
# Validation average reward after epoch 2: 4.0045
# Epoch [2/100], Batch [401/2500], Actor Loss: -0.0604, Reward: 4.0219
# Validation average reward after epoch 2: 3.9998
# Epoch [2/100], Batch [501/2500], Actor Loss: -0.2415, Reward: 4.0681
# Validation average reward after epoch 2: 4.0004
# Epoch [2/100], Batch [601/2500], Actor Loss: -0.1375, Reward: 4.0322
# Validation average reward after epoch 2: 4.0010
# Epoch [2/100], Batch [701/2500], Actor Loss: -0.0903, Reward: 4.0189
# Validation average reward after epoch 2: 3.9977
# Epoch [2/100], Batch [801/2500], Actor Loss: -0.3258, Reward: 4.0797
# Validation average reward after epoch 2: 4.0017
# Epoch [2/100], Batch [901/2500], Actor Loss: -0.1856, Reward: 4.0397
# Validation average reward after epoch 2: 3.9952
# Epoch [2/100], Batch [1001/2500], Actor Loss: -0.0814, Reward: 4.0232
# Validation average reward after epoch 2: 3.9918
# Epoch [2/100], Batch [1101/2500], Actor Loss: -0.1291, Reward: 4.0240
# Validation average reward after epoch 2: 3.9960
# Epoch [2/100], Batch [1201/2500], Actor Loss: -0.0473, Reward: 4.0305
# Validation average reward after epoch 2: 4.0006
# Epoch [2/100], Batch [1301/2500], Actor Loss: -0.0376, Reward: 3.9991
# Validation average reward after epoch 2: 3.9986
# Epoch [2/100], Batch [1401/2500], Actor Loss: -0.0774, Reward: 4.0213
# Validation average reward after epoch 2: 3.9899
# Epoch [2/100], Batch [1501/2500], Actor Loss: -0.2443, Reward: 4.0371
# Validation average reward after epoch 2: 3.9893
# Epoch [2/100], Batch [1601/2500], Actor Loss: -0.0342, Reward: 4.0124
# Validation average reward after epoch 2: 3.9949
# Epoch [2/100], Batch [1701/2500], Actor Loss: -0.0465, Reward: 3.9929
# Validation average reward after epoch 2: 3.9802
# Epoch [2/100], Batch [1801/2500], Actor Loss: -0.0866, Reward: 3.9995
# Validation average reward after epoch 2: 3.9852
# Epoch [2/100], Batch [1901/2500], Actor Loss: -0.3367, Reward: 4.0108
# Validation average reward after epoch 2: 3.9790
# Epoch [2/100], Batch [2001/2500], Actor Loss: -0.4617, Reward: 4.0499
# Validation average reward after epoch 2: 3.9817
# Epoch [2/100], Batch [2101/2500], Actor Loss: -0.1761, Reward: 4.0406
# Validation average reward after epoch 2: 3.9832
# Epoch [2/100], Batch [2201/2500], Actor Loss: -0.0394, Reward: 3.9916
# Validation average reward after epoch 2: 3.9800
# Epoch [2/100], Batch [2301/2500], Actor Loss: -0.1887, Reward: 4.0122
# Validation average reward after epoch 2: 3.9888
# Epoch [2/100], Batch [2401/2500], Actor Loss: -0.1695, Reward: 4.0180
# Validation average reward after epoch 2: 3.9752
# Epoch [3/100], Batch [1/2500], Actor Loss: -0.1059, Reward: 4.0024
# Validation average reward after epoch 3: 3.9766
# Epoch [3/100], Batch [101/2500], Actor Loss: -0.0591, Reward: 3.9915
# Validation average reward after epoch 3: 3.9801
# Epoch [3/100], Batch [201/2500], Actor Loss: -0.1059, Reward: 4.0178
# Validation average reward after epoch 3: 3.9862
# Epoch [3/100], Batch [301/2500], Actor Loss: -0.1687, Reward: 4.0354
# Validation average reward after epoch 3: 3.9792
# Epoch [3/100], Batch [401/2500], Actor Loss: -0.0070, Reward: 4.0042
# Validation average reward after epoch 3: 3.9982
# Epoch [3/100], Batch [501/2500], Actor Loss: -0.0771, Reward: 4.0035
# Validation average reward after epoch 3: 3.9728
# Epoch [3/100], Batch [601/2500], Actor Loss: -0.1532, Reward: 4.0206
# Validation average reward after epoch 3: 3.9676
# Epoch [3/100], Batch [701/2500], Actor Loss: -0.1463, Reward: 3.9949
# Validation average reward after epoch 3: 3.9820
# Epoch [3/100], Batch [801/2500], Actor Loss: 0.0358, Reward: 3.9763
# Validation average reward after epoch 3: 3.9639
# Epoch [3/100], Batch [901/2500], Actor Loss: -0.1199, Reward: 3.9994
# Validation average reward after epoch 3: 3.9657
# Epoch [3/100], Batch [1001/2500], Actor Loss: -0.1179, Reward: 4.0043
# Validation average reward after epoch 3: 3.9828
# Epoch [3/100], Batch [1101/2500], Actor Loss: -0.0640, Reward: 3.9910
# Validation average reward after epoch 3: 3.9851
# Epoch [3/100], Batch [1201/2500], Actor Loss: -0.0045, Reward: 3.9547
# Validation average reward after epoch 3: 3.9672
# Epoch [3/100], Batch [1301/2500], Actor Loss: -0.1152, Reward: 4.0230
# Validation average reward after epoch 3: 3.9796
# Epoch [3/100], Batch [1401/2500], Actor Loss: 0.0148, Reward: 3.9768
# Validation average reward after epoch 3: 3.9736
# Epoch [3/100], Batch [1501/2500], Actor Loss: -0.0582, Reward: 3.9863
# Validation average reward after epoch 3: 3.9675
# Epoch [3/100], Batch [1601/2500], Actor Loss: -0.1359, Reward: 4.0100
# Validation average reward after epoch 3: 3.9697
# Epoch [3/100], Batch [1701/2500], Actor Loss: -0.0887, Reward: 3.9900
# Validation average reward after epoch 3: 3.9682
# Epoch [3/100], Batch [1801/2500], Actor Loss: -0.1018, Reward: 3.9857
# Validation average reward after epoch 3: 3.9683
# Epoch [3/100], Batch [1901/2500], Actor Loss: -0.0408, Reward: 3.9901
# Validation average reward after epoch 3: 3.9644
# Epoch [3/100], Batch [2001/2500], Actor Loss: -0.0840, Reward: 3.9861
# Validation average reward after epoch 3: 3.9626
# Epoch [3/100], Batch [2101/2500], Actor Loss: -0.0695, Reward: 3.9803
# Validation average reward after epoch 3: 3.9627
# Epoch [3/100], Batch [2201/2500], Actor Loss: -0.0030, Reward: 3.9651
# Validation average reward after epoch 3: 3.9618
# Epoch [3/100], Batch [2301/2500], Actor Loss: -0.0806, Reward: 3.9927
# Validation average reward after epoch 3: 3.9629
# Epoch [3/100], Batch [2401/2500], Actor Loss: -0.2081, Reward: 3.9945
# Validation average reward after epoch 3: 3.9563
# Epoch [4/100], Batch [1/2500], Actor Loss: -0.0654, Reward: 3.9778
# Validation average reward after epoch 4: 3.9587
# Epoch [4/100], Batch [101/2500], Actor Loss: -0.0741, Reward: 3.9954
# Validation average reward after epoch 4: 3.9551
# Epoch [4/100], Batch [201/2500], Actor Loss: -0.0560, Reward: 3.9769
# Validation average reward after epoch 4: 3.9526
# Epoch [4/100], Batch [301/2500], Actor Loss: -0.1236, Reward: 3.9940
# Validation average reward after epoch 4: 3.9574
# Epoch [4/100], Batch [401/2500], Actor Loss: -0.0595, Reward: 3.9779
# Validation average reward after epoch 4: 3.9584
# Epoch [4/100], Batch [501/2500], Actor Loss: -0.0930, Reward: 3.9964
# Validation average reward after epoch 4: 3.9604
# Epoch [4/100], Batch [601/2500], Actor Loss: -0.0262, Reward: 3.9649
# Validation average reward after epoch 4: 3.9554
# Epoch [4/100], Batch [701/2500], Actor Loss: -0.0223, Reward: 3.9590
# Validation average reward after epoch 4: 3.9563
# Epoch [4/100], Batch [801/2500], Actor Loss: -0.0477, Reward: 3.9787
# Validation average reward after epoch 4: 3.9573
# Epoch [4/100], Batch [901/2500], Actor Loss: -0.1829, Reward: 4.0113
# Validation average reward after epoch 4: 3.9656
# Epoch [4/100], Batch [1001/2500], Actor Loss: -0.1213, Reward: 3.9846
# Validation average reward after epoch 4: 3.9653
# Epoch [4/100], Batch [1101/2500], Actor Loss: 0.0313, Reward: 3.9611
# Validation average reward after epoch 4: 3.9504
# Epoch [4/100], Batch [1201/2500], Actor Loss: -0.0855, Reward: 3.9775
# Validation average reward after epoch 4: 3.9599
# Epoch [4/100], Batch [1301/2500], Actor Loss: -0.0604, Reward: 3.9641
# Validation average reward after epoch 4: 3.9517
# Epoch [4/100], Batch [1401/2500], Actor Loss: -0.0660, Reward: 3.9735
# Validation average reward after epoch 4: 3.9565
# Epoch [4/100], Batch [1501/2500], Actor Loss: -0.0035, Reward: 3.9560
# Validation average reward after epoch 4: 3.9458
# Epoch [4/100], Batch [1601/2500], Actor Loss: -0.1960, Reward: 3.9891
# Validation average reward after epoch 4: 3.9569
# Epoch [4/100], Batch [1701/2500], Actor Loss: -0.0444, Reward: 3.9602
# Validation average reward after epoch 4: 3.9556
# Epoch [4/100], Batch [1801/2500], Actor Loss: -0.0234, Reward: 3.9631
# Validation average reward after epoch 4: 3.9607
# Epoch [4/100], Batch [1901/2500], Actor Loss: -0.0879, Reward: 3.9736
# Validation average reward after epoch 4: 3.9484
# Epoch [4/100], Batch [2001/2500], Actor Loss: -0.0831, Reward: 3.9766
# Validation average reward after epoch 4: 3.9451
# Epoch [4/100], Batch [2101/2500], Actor Loss: 0.0296, Reward: 3.9575
# Validation average reward after epoch 4: 3.9628
# Epoch [4/100], Batch [2201/2500], Actor Loss: -0.0946, Reward: 3.9717
# Validation average reward after epoch 4: 3.9602
# Epoch [4/100], Batch [2301/2500], Actor Loss: -0.0760, Reward: 3.9820
# Validation average reward after epoch 4: 3.9454
# Epoch [4/100], Batch [2401/2500], Actor Loss: -0.0363, Reward: 3.9747
# Validation average reward after epoch 4: 3.9567
# Epoch [5/100], Batch [1/2500], Actor Loss: -0.0275, Reward: 3.9720
# Validation average reward after epoch 5: 3.9519
# Epoch [5/100], Batch [101/2500], Actor Loss: -0.0920, Reward: 3.9912
# Validation average reward after epoch 5: 3.9420
# Epoch [5/100], Batch [201/2500], Actor Loss: -0.1140, Reward: 3.9878
# Validation average reward after epoch 5: 3.9480
# Epoch [5/100], Batch [301/2500], Actor Loss: -0.0431, Reward: 3.9668
# Validation average reward after epoch 5: 3.9467
# Epoch [5/100], Batch [401/2500], Actor Loss: -0.0823, Reward: 3.9799
# Validation average reward after epoch 5: 3.9469
# Epoch [5/100], Batch [501/2500], Actor Loss: -0.0924, Reward: 3.9781
# Validation average reward after epoch 5: 3.9430
# Epoch [5/100], Batch [601/2500], Actor Loss: -0.1106, Reward: 4.0019
# Validation average reward after epoch 5: 3.9555
# Epoch [5/100], Batch [701/2500], Actor Loss: -0.0765, Reward: 3.9625
# Validation average reward after epoch 5: 3.9489
# Epoch [5/100], Batch [801/2500], Actor Loss: -0.0982, Reward: 4.0015
# Validation average reward after epoch 5: 3.9513
# Epoch [5/100], Batch [901/2500], Actor Loss: -0.2914, Reward: 4.0290
# Validation average reward after epoch 5: 3.9578
# Epoch [5/100], Batch [1001/2500], Actor Loss: 0.0539, Reward: 3.9224
# Validation average reward after epoch 5: 3.9403
# Epoch [5/100], Batch [1101/2500], Actor Loss: -0.1654, Reward: 3.9970
# Validation average reward after epoch 5: 3.9476
# Epoch [5/100], Batch [1201/2500], Actor Loss: -0.0696, Reward: 3.9679
# Validation average reward after epoch 5: 3.9490
# Epoch [5/100], Batch [1301/2500], Actor Loss: -0.1216, Reward: 3.9959
# Validation average reward after epoch 5: 3.9536
# Epoch [5/100], Batch [1401/2500], Actor Loss: -0.1252, Reward: 3.9854
# Validation average reward after epoch 5: 3.9499
# Epoch [5/100], Batch [1501/2500], Actor Loss: -0.1364, Reward: 3.9728
# Validation average reward after epoch 5: 3.9519
# Epoch [5/100], Batch [1601/2500], Actor Loss: -0.1356, Reward: 3.9953
# Validation average reward after epoch 5: 3.9475
# Epoch [5/100], Batch [1701/2500], Actor Loss: -0.1082, Reward: 3.9991
# Validation average reward after epoch 5: 3.9567
# Epoch [5/100], Batch [1801/2500], Actor Loss: -0.0632, Reward: 3.9767
# Validation average reward after epoch 5: 3.9476
# Epoch [5/100], Batch [1901/2500], Actor Loss: -0.0333, Reward: 3.9598
# Validation average reward after epoch 5: 3.9437
# Epoch [5/100], Batch [2001/2500], Actor Loss: -0.0948, Reward: 3.9753
# Validation average reward after epoch 5: 3.9398
# Epoch [5/100], Batch [2101/2500], Actor Loss: -0.0573, Reward: 3.9643
# Validation average reward after epoch 5: 3.9391
# Epoch [5/100], Batch [2201/2500], Actor Loss: -0.0591, Reward: 3.9615
# Validation average reward after epoch 5: 3.9419
# Epoch [5/100], Batch [2301/2500], Actor Loss: -0.1715, Reward: 3.9838
# Validation average reward after epoch 5: 3.9382
# Epoch [5/100], Batch [2401/2500], Actor Loss: -0.0145, Reward: 3.9544
# Validation average reward after epoch 5: 3.9339
# Epoch [6/100], Batch [1/2500], Actor Loss: -0.0684, Reward: 3.9680
# Validation average reward after epoch 6: 3.9366
# Epoch [6/100], Batch [101/2500], Actor Loss: -0.0263, Reward: 3.9532
# Validation average reward after epoch 6: 3.9399
# Epoch [6/100], Batch [201/2500], Actor Loss: -0.0666, Reward: 3.9617
# Validation average reward after epoch 6: 3.9390
# Epoch [6/100], Batch [301/2500], Actor Loss: -0.0358, Reward: 3.9526
# Validation average reward after epoch 6: 3.9392
# Epoch [6/100], Batch [401/2500], Actor Loss: -0.0793, Reward: 3.9774
# Validation average reward after epoch 6: 3.9444
# Epoch [6/100], Batch [501/2500], Actor Loss: -0.0862, Reward: 3.9607
# Validation average reward after epoch 6: 3.9452
# Epoch [6/100], Batch [601/2500], Actor Loss: -0.0582, Reward: 3.9534
# Validation average reward after epoch 6: 3.9433
# Epoch [6/100], Batch [701/2500], Actor Loss: -0.0723, Reward: 3.9693
# Validation average reward after epoch 6: 3.9508
# Epoch [6/100], Batch [801/2500], Actor Loss: -0.0198, Reward: 3.9541
# Validation average reward after epoch 6: 3.9395
# Epoch [6/100], Batch [901/2500], Actor Loss: -0.0292, Reward: 3.9511
# Validation average reward after epoch 6: 3.9474
# Epoch [6/100], Batch [1001/2500], Actor Loss: -0.0948, Reward: 3.9413
# Validation average reward after epoch 6: 3.9393
# Epoch [6/100], Batch [1101/2500], Actor Loss: -0.0848, Reward: 3.9650
# Validation average reward after epoch 6: 3.9300
# Epoch [6/100], Batch [1201/2500], Actor Loss: -0.0676, Reward: 3.9674
# Validation average reward after epoch 6: 3.9515
# Epoch [6/100], Batch [1301/2500], Actor Loss: -0.1375, Reward: 3.9999
# Validation average reward after epoch 6: 3.9507
# Epoch [6/100], Batch [1401/2500], Actor Loss: -0.0149, Reward: 3.9517
# Validation average reward after epoch 6: 3.9465
# Epoch [6/100], Batch [1501/2500], Actor Loss: -0.1534, Reward: 3.9715
# Validation average reward after epoch 6: 3.9369
# Epoch [6/100], Batch [1601/2500], Actor Loss: -0.1133, Reward: 3.9730
# Validation average reward after epoch 6: 3.9331
# Epoch [6/100], Batch [1701/2500], Actor Loss: -0.1903, Reward: 3.9994
# Validation average reward after epoch 6: 3.9390
# Epoch [6/100], Batch [1801/2500], Actor Loss: -0.0486, Reward: 3.9437
# Validation average reward after epoch 6: 3.9332
# Epoch [6/100], Batch [1901/2500], Actor Loss: -0.0542, Reward: 3.9618
# Validation average reward after epoch 6: 3.9467
# Epoch [6/100], Batch [2001/2500], Actor Loss: -0.0892, Reward: 3.9619
# Validation average reward after epoch 6: 3.9362
# Epoch [6/100], Batch [2101/2500], Actor Loss: -0.0745, Reward: 3.9608
# Validation average reward after epoch 6: 3.9508
# Epoch [6/100], Batch [2201/2500], Actor Loss: -0.0595, Reward: 3.9566
# Validation average reward after epoch 6: 3.9378
# Epoch [6/100], Batch [2301/2500], Actor Loss: -0.0598, Reward: 3.9514
# Validation average reward after epoch 6: 3.9277
# Epoch [6/100], Batch [2401/2500], Actor Loss: -0.0093, Reward: 3.9528
# Validation average reward after epoch 6: 3.9349
# Epoch [7/100], Batch [1/2500], Actor Loss: -0.0801, Reward: 3.9723
# Validation average reward after epoch 7: 3.9418
# Epoch [7/100], Batch [101/2500], Actor Loss: -0.0578, Reward: 3.9508
# Validation average reward after epoch 7: 3.9321
# Epoch [7/100], Batch [201/2500], Actor Loss: -0.0566, Reward: 3.9442
# Validation average reward after epoch 7: 3.9328
# Epoch [7/100], Batch [301/2500], Actor Loss: -0.0786, Reward: 3.9674
# Validation average reward after epoch 7: 3.9473
# Epoch [7/100], Batch [401/2500], Actor Loss: -0.0426, Reward: 3.9480
# Validation average reward after epoch 7: 3.9308
# Epoch [7/100], Batch [501/2500], Actor Loss: -0.1081, Reward: 3.9604
# Validation average reward after epoch 7: 3.9464
# Epoch [7/100], Batch [601/2500], Actor Loss: -0.0674, Reward: 3.9614
# Validation average reward after epoch 7: 3.9310
# Epoch [7/100], Batch [701/2500], Actor Loss: 0.0391, Reward: 3.9086
# Validation average reward after epoch 7: 3.9316
# Epoch [7/100], Batch [801/2500], Actor Loss: -0.1746, Reward: 3.9829
# Validation average reward after epoch 7: 3.9366
# Epoch [7/100], Batch [901/2500], Actor Loss: -0.0513, Reward: 3.9586
# Validation average reward after epoch 7: 3.9323
# Epoch [7/100], Batch [1001/2500], Actor Loss: -0.1120, Reward: 3.9708
# Validation average reward after epoch 7: 3.9343
# Epoch [7/100], Batch [1101/2500], Actor Loss: 0.0305, Reward: 3.9292
# Validation average reward after epoch 7: 3.9329
# Epoch [7/100], Batch [1201/2500], Actor Loss: -0.1065, Reward: 3.9414
# Validation average reward after epoch 7: 3.9351
# Epoch [7/100], Batch [1301/2500], Actor Loss: -0.0301, Reward: 3.9514
# Validation average reward after epoch 7: 3.9343
# Epoch [7/100], Batch [1401/2500], Actor Loss: -0.0201, Reward: 3.9598
# Validation average reward after epoch 7: 3.9367
# Epoch [7/100], Batch [1501/2500], Actor Loss: -0.1205, Reward: 3.9874
# Validation average reward after epoch 7: 3.9439
# Epoch [7/100], Batch [1601/2500], Actor Loss: -0.0339, Reward: 3.9574
# Validation average reward after epoch 7: 3.9263
# Epoch [7/100], Batch [1701/2500], Actor Loss: -0.1129, Reward: 3.9665
# Validation average reward after epoch 7: 3.9309
# Epoch [7/100], Batch [1801/2500], Actor Loss: -0.0366, Reward: 3.9392
# Validation average reward after epoch 7: 3.9283
# Epoch [7/100], Batch [1901/2500], Actor Loss: -0.0523, Reward: 3.9538
# Validation average reward after epoch 7: 3.9333
# Epoch [7/100], Batch [2001/2500], Actor Loss: -0.1264, Reward: 3.9643
# Validation average reward after epoch 7: 3.9455
# Epoch [7/100], Batch [2101/2500], Actor Loss: -0.1065, Reward: 3.9707
# Validation average reward after epoch 7: 3.9294
# Epoch [7/100], Batch [2201/2500], Actor Loss: 0.0265, Reward: 3.9406
# Validation average reward after epoch 7: 3.9415
# Epoch [7/100], Batch [2301/2500], Actor Loss: -0.0490, Reward: 3.9543
# Validation average reward after epoch 7: 3.9312
# Epoch [7/100], Batch [2401/2500], Actor Loss: -0.0816, Reward: 3.9567
# Validation average reward after epoch 7: 3.9301
# Epoch [8/100], Batch [1/2500], Actor Loss: 0.0112, Reward: 3.9323
# Validation average reward after epoch 8: 3.9270
# Epoch [8/100], Batch [101/2500], Actor Loss: -0.1391, Reward: 3.9749
# Validation average reward after epoch 8: 3.9370
# Epoch [8/100], Batch [201/2500], Actor Loss: -0.0189, Reward: 3.9514
# Validation average reward after epoch 8: 3.9462
# Epoch [8/100], Batch [301/2500], Actor Loss: -0.0580, Reward: 3.9487
# Validation average reward after epoch 8: 3.9280
# Epoch [8/100], Batch [401/2500], Actor Loss: -0.0355, Reward: 3.9546
# Validation average reward after epoch 8: 3.9351
# Epoch [8/100], Batch [501/2500], Actor Loss: -0.0538, Reward: 3.9480
# Validation average reward after epoch 8: 3.9237
# Epoch [8/100], Batch [601/2500], Actor Loss: -0.1584, Reward: 3.9528
# Validation average reward after epoch 8: 3.9352
# Epoch [8/100], Batch [701/2500], Actor Loss: -0.0153, Reward: 3.9388
# Validation average reward after epoch 8: 3.9269
# Epoch [8/100], Batch [801/2500], Actor Loss: -0.0194, Reward: 3.9509
# Validation average reward after epoch 8: 3.9273
# Epoch [8/100], Batch [901/2500], Actor Loss: -0.0596, Reward: 3.9595
# Validation average reward after epoch 8: 3.9320
# Epoch [8/100], Batch [1001/2500], Actor Loss: 0.0122, Reward: 3.9286
# Validation average reward after epoch 8: 3.9249
# Epoch [8/100], Batch [1101/2500], Actor Loss: -0.0293, Reward: 3.9378
# Validation average reward after epoch 8: 3.9303
# Epoch [8/100], Batch [1201/2500], Actor Loss: -0.0712, Reward: 3.9591
# Validation average reward after epoch 8: 3.9263
# Epoch [8/100], Batch [1301/2500], Actor Loss: -0.0673, Reward: 3.9448
# Validation average reward after epoch 8: 3.9210
# Epoch [8/100], Batch [1401/2500], Actor Loss: -0.2178, Reward: 3.9820
# Validation average reward after epoch 8: 3.9462
# Epoch [8/100], Batch [1501/2500], Actor Loss: -0.0738, Reward: 3.9655
# Validation average reward after epoch 8: 3.9285
# Epoch [8/100], Batch [1601/2500], Actor Loss: -0.0777, Reward: 3.9509
# Validation average reward after epoch 8: 3.9279
# Epoch [8/100], Batch [1701/2500], Actor Loss: -0.0778, Reward: 3.9620
# Validation average reward after epoch 8: 3.9338
# Epoch [8/100], Batch [1801/2500], Actor Loss: -0.0823, Reward: 3.9509
# Validation average reward after epoch 8: 3.9301
# Epoch [8/100], Batch [1901/2500], Actor Loss: -0.0524, Reward: 3.9481
# Validation average reward after epoch 8: 3.9260
# Epoch [8/100], Batch [2001/2500], Actor Loss: -0.1006, Reward: 3.9528
# Validation average reward after epoch 8: 3.9210
# Epoch [8/100], Batch [2101/2500], Actor Loss: -0.0473, Reward: 3.9347
# Validation average reward after epoch 8: 3.9209
# Epoch [8/100], Batch [2201/2500], Actor Loss: -0.2029, Reward: 3.9874
# Validation average reward after epoch 8: 3.9230
# Epoch [8/100], Batch [2301/2500], Actor Loss: -0.0868, Reward: 3.9452
# Validation average reward after epoch 8: 3.9223
# Epoch [8/100], Batch [2401/2500], Actor Loss: -0.0083, Reward: 3.9387
# Validation average reward after epoch 8: 3.9200
# Epoch [9/100], Batch [1/2500], Actor Loss: -0.0549, Reward: 3.9501
# Validation average reward after epoch 9: 3.9240
# Epoch [9/100], Batch [101/2500], Actor Loss: -0.1550, Reward: 3.9786
# Validation average reward after epoch 9: 3.9366
# Epoch [9/100], Batch [201/2500], Actor Loss: -0.1021, Reward: 3.9547
# Validation average reward after epoch 9: 3.9295
# Epoch [9/100], Batch [301/2500], Actor Loss: 0.0055, Reward: 3.9318
# Validation average reward after epoch 9: 3.9221
# Epoch [9/100], Batch [401/2500], Actor Loss: -0.0785, Reward: 3.9445
# Validation average reward after epoch 9: 3.9418
# Epoch [9/100], Batch [501/2500], Actor Loss: -0.0554, Reward: 3.9404
# Validation average reward after epoch 9: 3.9353
# Epoch [9/100], Batch [601/2500], Actor Loss: -0.0514, Reward: 3.9529
# Validation average reward after epoch 9: 3.9215
# Epoch [9/100], Batch [701/2500], Actor Loss: -0.0481, Reward: 3.9383
# Validation average reward after epoch 9: 3.9264
# Epoch [9/100], Batch [801/2500], Actor Loss: -0.0275, Reward: 3.9454
# Validation average reward after epoch 9: 3.9326
# Epoch [9/100], Batch [901/2500], Actor Loss: -0.0491, Reward: 3.9407
# Validation average reward after epoch 9: 3.9297
# Epoch [9/100], Batch [1001/2500], Actor Loss: -0.0844, Reward: 3.9628
# Validation average reward after epoch 9: 3.9247
# Epoch [9/100], Batch [1101/2500], Actor Loss: -0.1033, Reward: 3.9756
# Validation average reward after epoch 9: 3.9313
# Epoch [9/100], Batch [1201/2500], Actor Loss: -0.0307, Reward: 3.9501
# Validation average reward after epoch 9: 3.9316
# Epoch [9/100], Batch [1301/2500], Actor Loss: 0.0037, Reward: 3.9380
# Validation average reward after epoch 9: 3.9304
# Epoch [9/100], Batch [1401/2500], Actor Loss: -0.1064, Reward: 3.9526
# Validation average reward after epoch 9: 3.9205
# Epoch [9/100], Batch [1501/2500], Actor Loss: -0.0102, Reward: 3.9267
# Validation average reward after epoch 9: 3.9229
# Epoch [9/100], Batch [1601/2500], Actor Loss: -0.0263, Reward: 3.9334
# Validation average reward after epoch 9: 3.9231
# Epoch [9/100], Batch [1701/2500], Actor Loss: -0.0852, Reward: 3.9536
# Validation average reward after epoch 9: 3.9256
# Epoch [9/100], Batch [1801/2500], Actor Loss: -0.0332, Reward: 3.9417
# Validation average reward after epoch 9: 3.9244
# Epoch [9/100], Batch [1901/2500], Actor Loss: -0.0316, Reward: 3.9318
# Validation average reward after epoch 9: 3.9171
# Epoch [9/100], Batch [2001/2500], Actor Loss: -0.0637, Reward: 3.9533
# Validation average reward after epoch 9: 3.9272
# Epoch [9/100], Batch [2101/2500], Actor Loss: -0.1313, Reward: 3.9536
# Validation average reward after epoch 9: 3.9269
# Epoch [9/100], Batch [2201/2500], Actor Loss: -0.0115, Reward: 3.9273
# Validation average reward after epoch 9: 3.9179
# Epoch [9/100], Batch [2301/2500], Actor Loss: -0.1046, Reward: 3.9406
# Validation average reward after epoch 9: 3.9232
# Epoch [9/100], Batch [2401/2500], Actor Loss: -0.0259, Reward: 3.9241
# Validation average reward after epoch 9: 3.9240
# Epoch [10/100], Batch [1/2500], Actor Loss: -0.0461, Reward: 3.9548
# Validation average reward after epoch 10: 3.9229
# Epoch [10/100], Batch [101/2500], Actor Loss: -0.0765, Reward: 3.9506
# Validation average reward after epoch 10: 3.9360
# Epoch [10/100], Batch [201/2500], Actor Loss: -0.0731, Reward: 3.9655
# Validation average reward after epoch 10: 3.9351
# Epoch [10/100], Batch [301/2500], Actor Loss: 0.0002, Reward: 3.9281
# Validation average reward after epoch 10: 3.9184
# Epoch [10/100], Batch [401/2500], Actor Loss: -0.0456, Reward: 3.9622
# Validation average reward after epoch 10: 3.9212
# Epoch [10/100], Batch [501/2500], Actor Loss: -0.0537, Reward: 3.9540
# Validation average reward after epoch 10: 3.9237
# Epoch [10/100], Batch [601/2500], Actor Loss: -0.1254, Reward: 3.9690
# Validation average reward after epoch 10: 3.9240
# Epoch [10/100], Batch [701/2500], Actor Loss: -0.0131, Reward: 3.9241
# Validation average reward after epoch 10: 3.9223
# Epoch [10/100], Batch [801/2500], Actor Loss: -0.0016, Reward: 3.9152
# Validation average reward after epoch 10: 3.9251
# Epoch [10/100], Batch [901/2500], Actor Loss: -0.0478, Reward: 3.9418
# Validation average reward after epoch 10: 3.9330
# Epoch [10/100], Batch [1001/2500], Actor Loss: 0.0142, Reward: 3.9249
# Validation average reward after epoch 10: 3.9201
# Epoch [10/100], Batch [1101/2500], Actor Loss: -0.0504, Reward: 3.9440
# Validation average reward after epoch 10: 3.9225
# Epoch [10/100], Batch [1201/2500], Actor Loss: -0.0803, Reward: 3.9346
# Validation average reward after epoch 10: 3.9205
# Epoch [10/100], Batch [1301/2500], Actor Loss: -0.0449, Reward: 3.9391
# Validation average reward after epoch 10: 3.9247
# Epoch [10/100], Batch [1401/2500], Actor Loss: -0.1012, Reward: 3.9487
# Validation average reward after epoch 10: 3.9234
# Epoch [10/100], Batch [1501/2500], Actor Loss: -0.0140, Reward: 3.9479
# Validation average reward after epoch 10: 3.9205
# Epoch [10/100], Batch [1601/2500], Actor Loss: -0.0191, Reward: 3.9272
# Validation average reward after epoch 10: 3.9191
# Epoch [10/100], Batch [1701/2500], Actor Loss: -0.0760, Reward: 3.9556
# Validation average reward after epoch 10: 3.9240
# Epoch [10/100], Batch [1801/2500], Actor Loss: 0.0197, Reward: 3.9120
# Validation average reward after epoch 10: 3.9250
# Epoch [10/100], Batch [1901/2500], Actor Loss: 0.0075, Reward: 3.9389
# Validation average reward after epoch 10: 3.9220
# Epoch [10/100], Batch [2001/2500], Actor Loss: -0.0831, Reward: 3.9439
# Validation average reward after epoch 10: 3.9280
# Epoch [10/100], Batch [2101/2500], Actor Loss: -0.0746, Reward: 3.9450
# Validation average reward after epoch 10: 3.9268
# Epoch [10/100], Batch [2201/2500], Actor Loss: 0.0299, Reward: 3.9270
# Validation average reward after epoch 10: 3.9317
# Epoch [10/100], Batch [2301/2500], Actor Loss: -0.1343, Reward: 3.9664
# Validation average reward after epoch 10: 3.9242
# Epoch [10/100], Batch [2401/2500], Actor Loss: -0.0574, Reward: 3.9321
# Validation average reward after epoch 10: 3.9262
# Epoch [11/100], Batch [1/2500], Actor Loss: -0.1878, Reward: 3.9548
# Validation average reward after epoch 11: 3.9249
# Epoch [11/100], Batch [101/2500], Actor Loss: -0.0296, Reward: 3.9445
# Validation average reward after epoch 11: 3.9237
# Epoch [11/100], Batch [201/2500], Actor Loss: -0.0449, Reward: 3.9404
# Validation average reward after epoch 11: 3.9267
# Epoch [11/100], Batch [301/2500], Actor Loss: -0.1134, Reward: 3.9685
# Validation average reward after epoch 11: 3.9274
# Epoch [11/100], Batch [401/2500], Actor Loss: -0.0917, Reward: 3.9608
# Validation average reward after epoch 11: 3.9226
# Epoch [11/100], Batch [501/2500], Actor Loss: 0.0109, Reward: 3.9368
# Validation average reward after epoch 11: 3.9163
# Epoch [11/100], Batch [601/2500], Actor Loss: -0.0609, Reward: 3.9658
# Validation average reward after epoch 11: 3.9219
# Epoch [11/100], Batch [701/2500], Actor Loss: -0.0081, Reward: 3.9282
# Validation average reward after epoch 11: 3.9197
# Epoch [11/100], Batch [801/2500], Actor Loss: -0.1647, Reward: 3.9871
# Validation average reward after epoch 11: 3.9249
# Epoch [11/100], Batch [901/2500], Actor Loss: -0.1012, Reward: 3.9567
# Validation average reward after epoch 11: 3.9320
# Epoch [11/100], Batch [1001/2500], Actor Loss: -0.1377, Reward: 3.9455
# Validation average reward after epoch 11: 3.9185
# Epoch [11/100], Batch [1101/2500], Actor Loss: -0.0925, Reward: 3.9397
# Validation average reward after epoch 11: 3.9189
# Epoch [11/100], Batch [1201/2500], Actor Loss: -0.0839, Reward: 3.9384
# Validation average reward after epoch 11: 3.9254
# Epoch [11/100], Batch [1301/2500], Actor Loss: -0.0500, Reward: 3.9303
# Validation average reward after epoch 11: 3.9314
# Epoch [11/100], Batch [1401/2500], Actor Loss: -0.0679, Reward: 3.9368
# Validation average reward after epoch 11: 3.9191
# Epoch [11/100], Batch [1501/2500], Actor Loss: -0.0090, Reward: 3.9375
# Validation average reward after epoch 11: 3.9123
# Epoch [11/100], Batch [1601/2500], Actor Loss: -0.1894, Reward: 3.9737
# Validation average reward after epoch 11: 3.9226
# Epoch [11/100], Batch [1701/2500], Actor Loss: -0.0748, Reward: 3.9328
# Validation average reward after epoch 11: 3.9192
# Epoch [11/100], Batch [1801/2500], Actor Loss: -0.0704, Reward: 3.9365
# Validation average reward after epoch 11: 3.9166
# Epoch [11/100], Batch [1901/2500], Actor Loss: -0.0333, Reward: 3.9292
# Validation average reward after epoch 11: 3.9200
# Epoch [11/100], Batch [2001/2500], Actor Loss: -0.1064, Reward: 3.9633
# Validation average reward after epoch 11: 3.9128
# Epoch [11/100], Batch [2101/2500], Actor Loss: -0.0821, Reward: 3.9375
# Validation average reward after epoch 11: 3.9233
# Epoch [11/100], Batch [2201/2500], Actor Loss: -0.0665, Reward: 3.9551
# Validation average reward after epoch 11: 3.9217
# Epoch [11/100], Batch [2301/2500], Actor Loss: -0.0227, Reward: 3.9215
# Validation average reward after epoch 11: 3.9175
# Epoch [11/100], Batch [2401/2500], Actor Loss: -0.0193, Reward: 3.9224
# Validation average reward after epoch 11: 3.9182
# Epoch [12/100], Batch [1/2500], Actor Loss: -0.0614, Reward: 3.9364
# Validation average reward after epoch 12: 3.9112
# Epoch [12/100], Batch [101/2500], Actor Loss: -0.0924, Reward: 3.9497
# Validation average reward after epoch 12: 3.9148
# Epoch [12/100], Batch [201/2500], Actor Loss: -0.0768, Reward: 3.9621
# Validation average reward after epoch 12: 3.9160
# Epoch [12/100], Batch [301/2500], Actor Loss: -0.0650, Reward: 3.9364
# Validation average reward after epoch 12: 3.9186
# Epoch [12/100], Batch [401/2500], Actor Loss: -0.0694, Reward: 3.9272
# Validation average reward after epoch 12: 3.9240
# Epoch [12/100], Batch [501/2500], Actor Loss: -0.0561, Reward: 3.9322
# Validation average reward after epoch 12: 3.9199
# Epoch [12/100], Batch [601/2500], Actor Loss: -0.0434, Reward: 3.9167
# Validation average reward after epoch 12: 3.9169
# Epoch [12/100], Batch [701/2500], Actor Loss: 0.0106, Reward: 3.9307
# Validation average reward after epoch 12: 3.9199
# Epoch [12/100], Batch [801/2500], Actor Loss: -0.0775, Reward: 3.9335
# Validation average reward after epoch 12: 3.9141
# Epoch [12/100], Batch [901/2500], Actor Loss: 0.0193, Reward: 3.9028
# Validation average reward after epoch 12: 3.9068
# Epoch [12/100], Batch [1001/2500], Actor Loss: -0.1066, Reward: 3.9436
# Validation average reward after epoch 12: 3.9182
# Epoch [12/100], Batch [1101/2500], Actor Loss: -0.0609, Reward: 3.9292
# Validation average reward after epoch 12: 3.9154
# Epoch [12/100], Batch [1201/2500], Actor Loss: -0.0409, Reward: 3.9357
# Validation average reward after epoch 12: 3.9149
# Epoch [12/100], Batch [1301/2500], Actor Loss: -0.0784, Reward: 3.9351
# Validation average reward after epoch 12: 3.9173
# Epoch [12/100], Batch [1401/2500], Actor Loss: -0.0873, Reward: 3.9320
# Validation average reward after epoch 12: 3.9130
# Epoch [12/100], Batch [1501/2500], Actor Loss: -0.0417, Reward: 3.9343
# Validation average reward after epoch 12: 3.9203
# Epoch [12/100], Batch [1601/2500], Actor Loss: -0.1851, Reward: 3.9310
# Validation average reward after epoch 12: 3.9154
# Epoch [12/100], Batch [1701/2500], Actor Loss: -0.0977, Reward: 3.9285
# Validation average reward after epoch 12: 3.9156
# Epoch [12/100], Batch [1801/2500], Actor Loss: 0.0002, Reward: 3.9116
# Validation average reward after epoch 12: 3.9135
# Epoch [12/100], Batch [1901/2500], Actor Loss: -0.1296, Reward: 3.9389
# Validation average reward after epoch 12: 3.9230
# Epoch [12/100], Batch [2001/2500], Actor Loss: -0.0680, Reward: 3.9539
# Validation average reward after epoch 12: 3.9158
# Epoch [12/100], Batch [2101/2500], Actor Loss: -0.0929, Reward: 3.9561
# Validation average reward after epoch 12: 3.9227
# Epoch [12/100], Batch [2201/2500], Actor Loss: -0.0631, Reward: 3.9373
# Validation average reward after epoch 12: 3.9137
# Epoch [12/100], Batch [2301/2500], Actor Loss: -0.0571, Reward: 3.9516
# Validation average reward after epoch 12: 3.9130
# Epoch [12/100], Batch [2401/2500], Actor Loss: -0.1362, Reward: 3.9624
# Validation average reward after epoch 12: 3.9187
# Epoch [13/100], Batch [1/2500], Actor Loss: -0.1197, Reward: 3.9559
# Validation average reward after epoch 13: 3.9081
# Epoch [13/100], Batch [101/2500], Actor Loss: -0.1659, Reward: 3.9700
# Validation average reward after epoch 13: 3.9219
# Epoch [13/100], Batch [201/2500], Actor Loss: -0.0417, Reward: 3.9357
# Validation average reward after epoch 13: 3.9142
# Epoch [13/100], Batch [301/2500], Actor Loss: -0.0388, Reward: 3.9243
# Validation average reward after epoch 13: 3.9225
# Epoch [13/100], Batch [401/2500], Actor Loss: -0.0608, Reward: 3.9263
# Validation average reward after epoch 13: 3.9137
# Epoch [13/100], Batch [501/2500], Actor Loss: -0.0974, Reward: 3.9536
# Validation average reward after epoch 13: 3.9228
# Epoch [13/100], Batch [601/2500], Actor Loss: -0.0805, Reward: 3.9500
# Validation average reward after epoch 13: 3.9186
# Epoch [13/100], Batch [701/2500], Actor Loss: -0.0766, Reward: 3.9548
# Validation average reward after epoch 13: 3.9165
# Epoch [13/100], Batch [801/2500], Actor Loss: -0.0797, Reward: 3.9565
# Validation average reward after epoch 13: 3.9209
# Epoch [13/100], Batch [901/2500], Actor Loss: -0.0722, Reward: 3.9409
# Validation average reward after epoch 13: 3.9115
# Epoch [13/100], Batch [1001/2500], Actor Loss: -0.1477, Reward: 3.9544
# Validation average reward after epoch 13: 3.9143
# Epoch [13/100], Batch [1101/2500], Actor Loss: -0.1112, Reward: 3.9448
# Validation average reward after epoch 13: 3.9119
# Epoch [13/100], Batch [1201/2500], Actor Loss: -0.1322, Reward: 3.9422
# Validation average reward after epoch 13: 3.9141
# Epoch [13/100], Batch [1301/2500], Actor Loss: -0.0667, Reward: 3.9355
# Validation average reward after epoch 13: 3.9122
# Epoch [13/100], Batch [1401/2500], Actor Loss: -0.0467, Reward: 3.9313
# Validation average reward after epoch 13: 3.9178
# Epoch [13/100], Batch [1501/2500], Actor Loss: -0.0591, Reward: 3.9293
# Validation average reward after epoch 13: 3.9112
# Epoch [13/100], Batch [1601/2500], Actor Loss: -0.0228, Reward: 3.9037
# Validation average reward after epoch 13: 3.9120
# Epoch [13/100], Batch [1701/2500], Actor Loss: -0.0543, Reward: 3.9207
# Validation average reward after epoch 13: 3.9148
# Epoch [13/100], Batch [1801/2500], Actor Loss: -0.1258, Reward: 3.9382
# Validation average reward after epoch 13: 3.9291
# Epoch [13/100], Batch [1901/2500], Actor Loss: -0.0318, Reward: 3.9197
# Validation average reward after epoch 13: 3.9198
# Epoch [13/100], Batch [2001/2500], Actor Loss: -0.0673, Reward: 3.9391
# Validation average reward after epoch 13: 3.9149
# Epoch [13/100], Batch [2101/2500], Actor Loss: -0.0872, Reward: 3.9497
# Validation average reward after epoch 13: 3.9154
# Epoch [13/100], Batch [2201/2500], Actor Loss: -0.0802, Reward: 3.9539
# Validation average reward after epoch 13: 3.9213
# Epoch [13/100], Batch [2301/2500], Actor Loss: -0.1238, Reward: 3.9583
# Validation average reward after epoch 13: 3.9164
# Epoch [13/100], Batch [2401/2500], Actor Loss: -0.0248, Reward: 3.9215
# Validation average reward after epoch 13: 3.9130
# Epoch [14/100], Batch [1/2500], Actor Loss: -0.0828, Reward: 3.9353
# Validation average reward after epoch 14: 3.9115
# Epoch [14/100], Batch [101/2500], Actor Loss: -0.0098, Reward: 3.9024
# Validation average reward after epoch 14: 3.9138
# Epoch [14/100], Batch [201/2500], Actor Loss: -0.0827, Reward: 3.9439
# Validation average reward after epoch 14: 3.9155
# Epoch [14/100], Batch [301/2500], Actor Loss: -0.1139, Reward: 3.9611
# Validation average reward after epoch 14: 3.9169
# Epoch [14/100], Batch [401/2500], Actor Loss: 0.0089, Reward: 3.9232
# Validation average reward after epoch 14: 3.9074
# Epoch [14/100], Batch [501/2500], Actor Loss: -0.0549, Reward: 3.9427
# Validation average reward after epoch 14: 3.9208
# Epoch [14/100], Batch [601/2500], Actor Loss: -0.0802, Reward: 3.9570
# Validation average reward after epoch 14: 3.9221
# Epoch [14/100], Batch [701/2500], Actor Loss: -0.0259, Reward: 3.9329
# Validation average reward after epoch 14: 3.9142
# Epoch [14/100], Batch [801/2500], Actor Loss: -0.1097, Reward: 3.9393
# Validation average reward after epoch 14: 3.9127
# Epoch [14/100], Batch [901/2500], Actor Loss: -0.0165, Reward: 3.9266
# Validation average reward after epoch 14: 3.9143
# Epoch [14/100], Batch [1001/2500], Actor Loss: 0.0319, Reward: 3.9185
# Validation average reward after epoch 14: 3.9107
# Epoch [14/100], Batch [1101/2500], Actor Loss: -0.0981, Reward: 3.9595
# Validation average reward after epoch 14: 3.9120
# Epoch [14/100], Batch [1201/2500], Actor Loss: -0.0313, Reward: 3.9414
# Validation average reward after epoch 14: 3.9155
# Epoch [14/100], Batch [1301/2500], Actor Loss: -0.0965, Reward: 3.9351
# Validation average reward after epoch 14: 3.9206
# Epoch [14/100], Batch [1401/2500], Actor Loss: -0.0771, Reward: 3.9496
# Validation average reward after epoch 14: 3.9160
# Epoch [14/100], Batch [1501/2500], Actor Loss: -0.0931, Reward: 3.9373
# Validation average reward after epoch 14: 3.9226
# Epoch [14/100], Batch [1601/2500], Actor Loss: -0.1029, Reward: 3.9439
# Validation average reward after epoch 14: 3.9082
# Epoch [14/100], Batch [1701/2500], Actor Loss: -0.0749, Reward: 3.9301
# Validation average reward after epoch 14: 3.9087
# Epoch [14/100], Batch [1801/2500], Actor Loss: -0.0261, Reward: 3.9264
# Validation average reward after epoch 14: 3.9167
# Epoch [14/100], Batch [1901/2500], Actor Loss: -0.1118, Reward: 3.9482
# Validation average reward after epoch 14: 3.9164
# Epoch [14/100], Batch [2001/2500], Actor Loss: -0.0073, Reward: 3.9120
# Validation average reward after epoch 14: 3.9133
# Epoch [14/100], Batch [2101/2500], Actor Loss: -0.0587, Reward: 3.9455
# Validation average reward after epoch 14: 3.9117
# Epoch [14/100], Batch [2201/2500], Actor Loss: -0.0614, Reward: 3.9298
# Validation average reward after epoch 14: 3.9103
# Epoch [14/100], Batch [2301/2500], Actor Loss: -0.0500, Reward: 3.9285
# Validation average reward after epoch 14: 3.9138
# Epoch [14/100], Batch [2401/2500], Actor Loss: -0.0367, Reward: 3.9126
# Validation average reward after epoch 14: 3.9068
# Epoch [15/100], Batch [1/2500], Actor Loss: -0.1877, Reward: 3.9726
# Validation average reward after epoch 15: 3.9164
# Epoch [15/100], Batch [101/2500], Actor Loss: -0.0811, Reward: 3.9281
# Validation average reward after epoch 15: 3.9077
# Epoch [15/100], Batch [201/2500], Actor Loss: -0.0575, Reward: 3.9234
# Validation average reward after epoch 15: 3.9098
# Epoch [15/100], Batch [301/2500], Actor Loss: -0.1432, Reward: 3.9615
# Validation average reward after epoch 15: 3.9166
# Epoch [15/100], Batch [401/2500], Actor Loss: -0.0149, Reward: 3.9223
# Validation average reward after epoch 15: 3.9116
# Epoch [15/100], Batch [501/2500], Actor Loss: -0.0841, Reward: 3.9434
# Validation average reward after epoch 15: 3.9105
# Epoch [15/100], Batch [601/2500], Actor Loss: -0.0402, Reward: 3.9219
# Validation average reward after epoch 15: 3.9108
# Epoch [15/100], Batch [701/2500], Actor Loss: -0.0584, Reward: 3.9379
# Validation average reward after epoch 15: 3.9137
# Epoch [15/100], Batch [801/2500], Actor Loss: -0.0910, Reward: 3.9367
# Validation average reward after epoch 15: 3.9150
# Epoch [15/100], Batch [901/2500], Actor Loss: -0.0333, Reward: 3.9104
# Validation average reward after epoch 15: 3.9093
# Epoch [15/100], Batch [1001/2500], Actor Loss: -0.0479, Reward: 3.9443
# Validation average reward after epoch 15: 3.9165
# Epoch [15/100], Batch [1101/2500], Actor Loss: -0.0279, Reward: 3.9384
# Validation average reward after epoch 15: 3.9105
# Epoch [15/100], Batch [1201/2500], Actor Loss: -0.1062, Reward: 3.9207
# Validation average reward after epoch 15: 3.9147
# Epoch [15/100], Batch [1301/2500], Actor Loss: 0.0060, Reward: 3.9094
# Validation average reward after epoch 15: 3.9124
# Epoch [15/100], Batch [1401/2500], Actor Loss: -0.0604, Reward: 3.9394
# Validation average reward after epoch 15: 3.9113
# Epoch [15/100], Batch [1501/2500], Actor Loss: -0.0150, Reward: 3.9148
# Validation average reward after epoch 15: 3.9076
# Epoch [15/100], Batch [1601/2500], Actor Loss: -0.0564, Reward: 3.9518
# Validation average reward after epoch 15: 3.9163
# Epoch [15/100], Batch [1701/2500], Actor Loss: -0.0603, Reward: 3.9233
# Validation average reward after epoch 15: 3.9088
# Epoch [15/100], Batch [1801/2500], Actor Loss: 0.0090, Reward: 3.9144
# Validation average reward after epoch 15: 3.9130
# Epoch [15/100], Batch [1901/2500], Actor Loss: -0.0367, Reward: 3.9337
# Validation average reward after epoch 15: 3.9219
# Epoch [15/100], Batch [2001/2500], Actor Loss: -0.0950, Reward: 3.9556
# Validation average reward after epoch 15: 3.9209
# Epoch [15/100], Batch [2101/2500], Actor Loss: -0.0102, Reward: 3.9055
# Validation average reward after epoch 15: 3.9073
# Epoch [15/100], Batch [2201/2500], Actor Loss: -0.0774, Reward: 3.9346
# Validation average reward after epoch 15: 3.9161
# Epoch [15/100], Batch [2301/2500], Actor Loss: -0.0378, Reward: 3.9347
# Validation average reward after epoch 15: 3.9159
# Epoch [15/100], Batch [2401/2500], Actor Loss: -0.0445, Reward: 3.9241
# Validation average reward after epoch 15: 3.9207
# Epoch [16/100], Batch [1/2500], Actor Loss: -0.0461, Reward: 3.9458
# Validation average reward after epoch 16: 3.9070
# Epoch [16/100], Batch [101/2500], Actor Loss: -0.0003, Reward: 3.9167
# Validation average reward after epoch 16: 3.9052
# Epoch [16/100], Batch [201/2500], Actor Loss: -0.1433, Reward: 3.9600
# Validation average reward after epoch 16: 3.9100
# Epoch [16/100], Batch [301/2500], Actor Loss: -0.0166, Reward: 3.9024
# Validation average reward after epoch 16: 3.9064
# Epoch [16/100], Batch [401/2500], Actor Loss: 0.0259, Reward: 3.9104
# Validation average reward after epoch 16: 3.9113
# Epoch [16/100], Batch [501/2500], Actor Loss: -0.0564, Reward: 3.9209
# Validation average reward after epoch 16: 3.9158
# Epoch [16/100], Batch [601/2500], Actor Loss: -0.0653, Reward: 3.9423
# Validation average reward after epoch 16: 3.9122
# Epoch [16/100], Batch [701/2500], Actor Loss: -0.0320, Reward: 3.9293
# Validation average reward after epoch 16: 3.9077
# Epoch [16/100], Batch [801/2500], Actor Loss: -0.0670, Reward: 3.9393
# Validation average reward after epoch 16: 3.9131
# Epoch [16/100], Batch [901/2500], Actor Loss: -0.1089, Reward: 3.9397
# Validation average reward after epoch 16: 3.9117
# Epoch [16/100], Batch [1001/2500], Actor Loss: -0.0581, Reward: 3.9380
# Validation average reward after epoch 16: 3.9101
# Epoch [16/100], Batch [1101/2500], Actor Loss: -0.0535, Reward: 3.9390
# Validation average reward after epoch 16: 3.9087
# Epoch [16/100], Batch [1201/2500], Actor Loss: 0.0049, Reward: 3.9247
# Validation average reward after epoch 16: 3.9087
# Epoch [16/100], Batch [1301/2500], Actor Loss: -0.0363, Reward: 3.9258
# Validation average reward after epoch 16: 3.9072
# Epoch [16/100], Batch [1401/2500], Actor Loss: -0.0624, Reward: 3.9212
# Validation average reward after epoch 16: 3.9058
# Epoch [16/100], Batch [1501/2500], Actor Loss: -0.0355, Reward: 3.9070
# Validation average reward after epoch 16: 3.9107
# Epoch [16/100], Batch [1601/2500], Actor Loss: -0.0577, Reward: 3.9276
# Validation average reward after epoch 16: 3.9116
# Epoch [16/100], Batch [1701/2500], Actor Loss: -0.0112, Reward: 3.9212
# Validation average reward after epoch 16: 3.9100
# Epoch [16/100], Batch [1801/2500], Actor Loss: -0.0593, Reward: 3.9290
# Validation average reward after epoch 16: 3.9148
# Epoch [16/100], Batch [1901/2500], Actor Loss: -0.0123, Reward: 3.9111
# Validation average reward after epoch 16: 3.9119
# Epoch [16/100], Batch [2001/2500], Actor Loss: -0.0085, Reward: 3.9075
# Validation average reward after epoch 16: 3.9099
# Epoch [16/100], Batch [2101/2500], Actor Loss: -0.0246, Reward: 3.9271
# Validation average reward after epoch 16: 3.9070
# Epoch [16/100], Batch [2201/2500], Actor Loss: -0.0568, Reward: 3.9307
# Validation average reward after epoch 16: 3.9112
# Epoch [16/100], Batch [2301/2500], Actor Loss: -0.0827, Reward: 3.9274
# Validation average reward after epoch 16: 3.9110
# Epoch [16/100], Batch [2401/2500], Actor Loss: -0.0420, Reward: 3.9359
# Validation average reward after epoch 16: 3.9069
# Epoch [17/100], Batch [1/2500], Actor Loss: -0.0017, Reward: 3.9100
# Validation average reward after epoch 17: 3.9080
# Epoch [17/100], Batch [101/2500], Actor Loss: -0.0518, Reward: 3.9313
# Validation average reward after epoch 17: 3.9054
# Epoch [17/100], Batch [201/2500], Actor Loss: -0.0745, Reward: 3.9386
# Validation average reward after epoch 17: 3.9127
# Epoch [17/100], Batch [301/2500], Actor Loss: -0.0759, Reward: 3.9316
# Validation average reward after epoch 17: 3.9093
# Epoch [17/100], Batch [401/2500], Actor Loss: -0.0927, Reward: 3.9502
# Validation average reward after epoch 17: 3.9038
# ...
# Epoch [95/100], Batch [1701/2500], Actor Loss: -0.0372, Reward: 3.9001
# Validation average reward after epoch 95: 3.8772
# Epoch [95/100], Batch [1801/2500], Actor Loss: -0.0178, Reward: 3.8879
# Validation average reward after epoch 95: 3.8751
# Epoch [95/100], Batch [1901/2500], Actor Loss: -0.0372, Reward: 3.8846
# Validation average reward after epoch 95: 3.8734
# Epoch [95/100], Batch [2001/2500], Actor Loss: -0.0329, Reward: 3.8727
# Validation average reward after epoch 95: 3.8770
# Epoch [95/100], Batch [2101/2500], Actor Loss: -0.0362, Reward: 3.9007
# Validation average reward after epoch 95: 3.8749
# Epoch [95/100], Batch [2201/2500], Actor Loss: -0.0816, Reward: 3.8847
# Validation average reward after epoch 95: 3.8750
# Epoch [95/100], Batch [2301/2500], Actor Loss: -0.0606, Reward: 3.8924
# Validation average reward after epoch 95: 3.8779
# Epoch [95/100], Batch [2401/2500], Actor Loss: -0.0877, Reward: 3.8924
# Validation average reward after epoch 95: 3.8793
# Epoch [96/100], Batch [1/2500], Actor Loss: -0.0398, Reward: 3.8886
# Validation average reward after epoch 96: 3.8780
# Epoch [96/100], Batch [101/2500], Actor Loss: -0.0252, Reward: 3.8926
# Validation average reward after epoch 96: 3.8770
# Epoch [96/100], Batch [201/2500], Actor Loss: -0.0577, Reward: 3.9059
# Validation average reward after epoch 96: 3.8755
# Epoch [96/100], Batch [301/2500], Actor Loss: -0.0445, Reward: 3.8865
# Validation average reward after epoch 96: 3.8772
# Epoch [96/100], Batch [401/2500], Actor Loss: -0.0426, Reward: 3.8851
# Validation average reward after epoch 96: 3.8823
# Epoch [96/100], Batch [501/2500], Actor Loss: -0.0203, Reward: 3.8934
# Validation average reward after epoch 96: 3.8801
# Epoch [96/100], Batch [601/2500], Actor Loss: -0.0492, Reward: 3.8960
# Validation average reward after epoch 96: 3.8749
# Epoch [96/100], Batch [701/2500], Actor Loss: -0.0727, Reward: 3.8987
# Validation average reward after epoch 96: 3.8783
# Epoch [96/100], Batch [801/2500], Actor Loss: -0.0649, Reward: 3.8776
# Validation average reward after epoch 96: 3.8779
# Epoch [96/100], Batch [901/2500], Actor Loss: 0.0267, Reward: 3.8665
# Validation average reward after epoch 96: 3.8726
# Epoch [96/100], Batch [1001/2500], Actor Loss: -0.0281, Reward: 3.8842
# Validation average reward after epoch 96: 3.8772
# Epoch [96/100], Batch [1101/2500], Actor Loss: -0.0697, Reward: 3.9071
# Validation average reward after epoch 96: 3.8760
# Epoch [96/100], Batch [1201/2500], Actor Loss: -0.0430, Reward: 3.8938
# Validation average reward after epoch 96: 3.8742
# Epoch [96/100], Batch [1301/2500], Actor Loss: -0.0315, Reward: 3.9055
# Validation average reward after epoch 96: 3.8784
# Epoch [96/100], Batch [1401/2500], Actor Loss: -0.0210, Reward: 3.9095
# Validation average reward after epoch 96: 3.8769
# Epoch [96/100], Batch [1501/2500], Actor Loss: -0.0239, Reward: 3.8761
# Validation average reward after epoch 96: 3.8834
# Epoch [96/100], Batch [1601/2500], Actor Loss: -0.0154, Reward: 3.8796
# Validation average reward after epoch 96: 3.8743
# Epoch [96/100], Batch [1701/2500], Actor Loss: -0.0462, Reward: 3.8834
# Validation average reward after epoch 96: 3.8740
# Epoch [96/100], Batch [1801/2500], Actor Loss: -0.0374, Reward: 3.8913
# Validation average reward after epoch 96: 3.8759
# Epoch [96/100], Batch [1901/2500], Actor Loss: -0.0086, Reward: 3.8884
# Validation average reward after epoch 96: 3.8791
# Epoch [96/100], Batch [2001/2500], Actor Loss: -0.0435, Reward: 3.9006
# Validation average reward after epoch 96: 3.8792
# Epoch [96/100], Batch [2101/2500], Actor Loss: 0.0257, Reward: 3.8654
# Validation average reward after epoch 96: 3.8757
# Epoch [96/100], Batch [2201/2500], Actor Loss: -0.0296, Reward: 3.8717
# Validation average reward after epoch 96: 3.8772
# Epoch [96/100], Batch [2301/2500], Actor Loss: -0.0307, Reward: 3.8986
# Validation average reward after epoch 96: 3.8758
# Epoch [96/100], Batch [2401/2500], Actor Loss: -0.0220, Reward: 3.8661
# Validation average reward after epoch 96: 3.8754
# Epoch [97/100], Batch [1/2500], Actor Loss: -0.0675, Reward: 3.8878
# Validation average reward after epoch 97: 3.8814
# Epoch [97/100], Batch [101/2500], Actor Loss: -0.0323, Reward: 3.8850
# Validation average reward after epoch 97: 3.8774
# Epoch [97/100], Batch [201/2500], Actor Loss: -0.0059, Reward: 3.8760
# Validation average reward after epoch 97: 3.8784
# Epoch [97/100], Batch [301/2500], Actor Loss: -0.0522, Reward: 3.8970
# Validation average reward after epoch 97: 3.8787
# Epoch [97/100], Batch [401/2500], Actor Loss: -0.0341, Reward: 3.8933
# Validation average reward after epoch 97: 3.8801
# Epoch [97/100], Batch [501/2500], Actor Loss: -0.0194, Reward: 3.8871
# Validation average reward after epoch 97: 3.8778
# Epoch [97/100], Batch [601/2500], Actor Loss: -0.0552, Reward: 3.9091
# Validation average reward after epoch 97: 3.8807
# Epoch [97/100], Batch [701/2500], Actor Loss: -0.1003, Reward: 3.9018
# Validation average reward after epoch 97: 3.8756
# Epoch [97/100], Batch [801/2500], Actor Loss: -0.0846, Reward: 3.9025
# Validation average reward after epoch 97: 3.8761
# Epoch [97/100], Batch [901/2500], Actor Loss: -0.0619, Reward: 3.8709
# Validation average reward after epoch 97: 3.8775
# Epoch [97/100], Batch [1001/2500], Actor Loss: -0.0362, Reward: 3.8864
# Validation average reward after epoch 97: 3.8780
# Epoch [97/100], Batch [1101/2500], Actor Loss: -0.0419, Reward: 3.9020
# Validation average reward after epoch 97: 3.8759
# Epoch [97/100], Batch [1201/2500], Actor Loss: -0.0254, Reward: 3.8735
# Validation average reward after epoch 97: 3.8749
# Epoch [97/100], Batch [1301/2500], Actor Loss: -0.0240, Reward: 3.8845
# Validation average reward after epoch 97: 3.8787
# Epoch [97/100], Batch [1401/2500], Actor Loss: -0.1127, Reward: 3.8986
# Validation average reward after epoch 97: 3.8774
# Epoch [97/100], Batch [1501/2500], Actor Loss: -0.0502, Reward: 3.9002
# Validation average reward after epoch 97: 3.8818
# Epoch [97/100], Batch [1601/2500], Actor Loss: -0.0419, Reward: 3.8780
# Validation average reward after epoch 97: 3.8807
# Epoch [97/100], Batch [1701/2500], Actor Loss: -0.0103, Reward: 3.8832
# Validation average reward after epoch 97: 3.8795
# Epoch [97/100], Batch [1801/2500], Actor Loss: -0.0262, Reward: 3.8865
# Validation average reward after epoch 97: 3.8782
# Epoch [97/100], Batch [1901/2500], Actor Loss: -0.0472, Reward: 3.8918
# Validation average reward after epoch 97: 3.8760
# Epoch [97/100], Batch [2001/2500], Actor Loss: -0.0200, Reward: 3.8828
# Validation average reward after epoch 97: 3.8772
# Epoch [97/100], Batch [2101/2500], Actor Loss: -0.0073, Reward: 3.8885
# Validation average reward after epoch 97: 3.8799
# Epoch [97/100], Batch [2201/2500], Actor Loss: -0.0847, Reward: 3.9045
# Validation average reward after epoch 97: 3.8788
# Epoch [97/100], Batch [2301/2500], Actor Loss: -0.0267, Reward: 3.8849
# Validation average reward after epoch 97: 3.8754
# Epoch [97/100], Batch [2401/2500], Actor Loss: -0.0308, Reward: 3.9066
# Validation average reward after epoch 97: 3.8784
# Epoch [98/100], Batch [1/2500], Actor Loss: -0.0695, Reward: 3.9029
# Validation average reward after epoch 98: 3.8720
# Epoch [98/100], Batch [101/2500], Actor Loss: -0.0584, Reward: 3.8866
# Validation average reward after epoch 98: 3.8770
# Epoch [98/100], Batch [201/2500], Actor Loss: -0.0177, Reward: 3.8947
# Validation average reward after epoch 98: 3.8767
# Epoch [98/100], Batch [301/2500], Actor Loss: -0.0424, Reward: 3.9053
# Validation average reward after epoch 98: 3.8755
# Epoch [98/100], Batch [401/2500], Actor Loss: -0.0033, Reward: 3.8795
# Validation average reward after epoch 98: 3.8782
# Epoch [98/100], Batch [501/2500], Actor Loss: -0.0773, Reward: 3.9070
# Validation average reward after epoch 98: 3.8785
# Epoch [98/100], Batch [601/2500], Actor Loss: -0.0330, Reward: 3.9078
# Validation average reward after epoch 98: 3.8774
# Epoch [98/100], Batch [701/2500], Actor Loss: -0.0406, Reward: 3.8981
# Validation average reward after epoch 98: 3.8806
# Epoch [98/100], Batch [801/2500], Actor Loss: -0.0117, Reward: 3.8607
# Validation average reward after epoch 98: 3.8789
# Epoch [98/100], Batch [901/2500], Actor Loss: -0.0265, Reward: 3.8820
# Validation average reward after epoch 98: 3.8788
# Epoch [98/100], Batch [1001/2500], Actor Loss: -0.0509, Reward: 3.8933
# Validation average reward after epoch 98: 3.8814
# Epoch [98/100], Batch [1101/2500], Actor Loss: -0.0479, Reward: 3.8968
# Validation average reward after epoch 98: 3.8749
# Epoch [98/100], Batch [1201/2500], Actor Loss: -0.0748, Reward: 3.9087
# Validation average reward after epoch 98: 3.8769
# Epoch [98/100], Batch [1301/2500], Actor Loss: -0.0439, Reward: 3.8940
# Validation average reward after epoch 98: 3.8805
# Epoch [98/100], Batch [1401/2500], Actor Loss: -0.0587, Reward: 3.8949
# Validation average reward after epoch 98: 3.8781
# Epoch [98/100], Batch [1501/2500], Actor Loss: -0.0200, Reward: 3.8939
# Validation average reward after epoch 98: 3.8830
# Epoch [98/100], Batch [1601/2500], Actor Loss: -0.0058, Reward: 3.8878
# Validation average reward after epoch 98: 3.8827
# Epoch [98/100], Batch [1701/2500], Actor Loss: -0.0542, Reward: 3.9135
# Validation average reward after epoch 98: 3.8798
# Epoch [98/100], Batch [1801/2500], Actor Loss: -0.0843, Reward: 3.9168
# Validation average reward after epoch 98: 3.8794
# Epoch [98/100], Batch [1901/2500], Actor Loss: -0.0781, Reward: 3.8965
# Validation average reward after epoch 98: 3.8770
# Epoch [98/100], Batch [2001/2500], Actor Loss: 0.0220, Reward: 3.8779
# Validation average reward after epoch 98: 3.8777
# Epoch [98/100], Batch [2101/2500], Actor Loss: -0.0414, Reward: 3.9143
# Validation average reward after epoch 98: 3.8807
# Epoch [98/100], Batch [2201/2500], Actor Loss: -0.0321, Reward: 3.8656
# Validation average reward after epoch 98: 3.8736
# Epoch [98/100], Batch [2301/2500], Actor Loss: -0.0005, Reward: 3.8935
# Validation average reward after epoch 98: 3.8830
# Epoch [98/100], Batch [2401/2500], Actor Loss: -0.0188, Reward: 3.8573
# Validation average reward after epoch 98: 3.8747
# Epoch [99/100], Batch [1/2500], Actor Loss: -0.0219, Reward: 3.8803
# Validation average reward after epoch 99: 3.8771
# Epoch [99/100], Batch [101/2500], Actor Loss: -0.0219, Reward: 3.8720
# Validation average reward after epoch 99: 3.8812
# Epoch [99/100], Batch [201/2500], Actor Loss: -0.0446, Reward: 3.8681
# Validation average reward after epoch 99: 3.8752
# Epoch [99/100], Batch [301/2500], Actor Loss: -0.1083, Reward: 3.9128
# Validation average reward after epoch 99: 3.8789
# Epoch [99/100], Batch [401/2500], Actor Loss: -0.0753, Reward: 3.8930
# Validation average reward after epoch 99: 3.8735
# Epoch [99/100], Batch [501/2500], Actor Loss: 0.0116, Reward: 3.8629
# Validation average reward after epoch 99: 3.8787
# Epoch [99/100], Batch [601/2500], Actor Loss: -0.0437, Reward: 3.8964
# Validation average reward after epoch 99: 3.8763
# Epoch [99/100], Batch [701/2500], Actor Loss: -0.0165, Reward: 3.8899
# Validation average reward after epoch 99: 3.8803
# Epoch [99/100], Batch [801/2500], Actor Loss: -0.0428, Reward: 3.9166
# Validation average reward after epoch 99: 3.8817
# Epoch [99/100], Batch [901/2500], Actor Loss: 0.0124, Reward: 3.8599
# Validation average reward after epoch 99: 3.8834
# Epoch [99/100], Batch [1001/2500], Actor Loss: -0.0258, Reward: 3.9020
# Validation average reward after epoch 99: 3.8822
# Epoch [99/100], Batch [1101/2500], Actor Loss: -0.0451, Reward: 3.8858
# Validation average reward after epoch 99: 3.8798
# Epoch [99/100], Batch [1201/2500], Actor Loss: -0.0306, Reward: 3.9206
# Validation average reward after epoch 99: 3.8791
# Epoch [99/100], Batch [1301/2500], Actor Loss: -0.0309, Reward: 3.8966
# Validation average reward after epoch 99: 3.8817
# Epoch [99/100], Batch [1401/2500], Actor Loss: -0.0379, Reward: 3.9092
# Validation average reward after epoch 99: 3.8805
# Epoch [99/100], Batch [1501/2500], Actor Loss: -0.0314, Reward: 3.9069
# Validation average reward after epoch 99: 3.8732
# Epoch [99/100], Batch [1601/2500], Actor Loss: -0.0023, Reward: 3.8735
# Validation average reward after epoch 99: 3.8765
# Epoch [99/100], Batch [1701/2500], Actor Loss: -0.0203, Reward: 3.8934
# Validation average reward after epoch 99: 3.8802
# Epoch [99/100], Batch [1801/2500], Actor Loss: -0.0639, Reward: 3.8965
# Validation average reward after epoch 99: 3.8789
# Epoch [99/100], Batch [1901/2500], Actor Loss: -0.0927, Reward: 3.8969
# Validation average reward after epoch 99: 3.8751
# Epoch [99/100], Batch [2001/2500], Actor Loss: -0.0127, Reward: 3.8774
# Validation average reward after epoch 99: 3.8770
# Epoch [99/100], Batch [2101/2500], Actor Loss: -0.0067, Reward: 3.8831
# Validation average reward after epoch 99: 3.8840
# Epoch [99/100], Batch [2201/2500], Actor Loss: -0.0573, Reward: 3.8890
# Validation average reward after epoch 99: 3.8753
# Epoch [99/100], Batch [2301/2500], Actor Loss: -0.0264, Reward: 3.9080
# Validation average reward after epoch 99: 3.8772
# Epoch [99/100], Batch [2401/2500], Actor Loss: -0.0300, Reward: 3.9054
# Validation average reward after epoch 99: 3.8764
# Epoch [100/100], Batch [1/2500], Actor Loss: 0.0347, Reward: 3.8500
# Validation average reward after epoch 100: 3.8780
# Epoch [100/100], Batch [101/2500], Actor Loss: -0.0590, Reward: 3.9038
# Validation average reward after epoch 100: 3.8761
# Epoch [100/100], Batch [201/2500], Actor Loss: 0.0041, Reward: 3.8923
# Validation average reward after epoch 100: 3.8825
# Epoch [100/100], Batch [301/2500], Actor Loss: -0.0398, Reward: 3.8789
# Validation average reward after epoch 100: 3.8759
# Epoch [100/100], Batch [401/2500], Actor Loss: -0.0284, Reward: 3.9081
# Validation average reward after epoch 100: 3.8822
# Epoch [100/100], Batch [501/2500], Actor Loss: -0.0099, Reward: 3.8796
# Validation average reward after epoch 100: 3.8802
# Epoch [100/100], Batch [601/2500], Actor Loss: 0.0005, Reward: 3.8720
# Validation average reward after epoch 100: 3.8782
# Epoch [100/100], Batch [701/2500], Actor Loss: -0.0082, Reward: 3.8789
# Validation average reward after epoch 100: 3.8749
# Epoch [100/100], Batch [801/2500], Actor Loss: -0.0003, Reward: 3.8873
# Validation average reward after epoch 100: 3.8740
# Epoch [100/100], Batch [901/2500], Actor Loss: -0.0611, Reward: 3.9062
# Validation average reward after epoch 100: 3.8753
# Epoch [100/100], Batch [1001/2500], Actor Loss: -0.0046, Reward: 3.8896
# Validation average reward after epoch 100: 3.8764
# Epoch [100/100], Batch [1101/2500], Actor Loss: -0.0152, Reward: 3.9052
# Validation average reward after epoch 100: 3.8805
# Epoch [100/100], Batch [1201/2500], Actor Loss: 0.0088, Reward: 3.8826
# Validation average reward after epoch 100: 3.8777
# Epoch [100/100], Batch [1301/2500], Actor Loss: -0.0304, Reward: 3.8881
# Validation average reward after epoch 100: 3.8784
# Epoch [100/100], Batch [1401/2500], Actor Loss: -0.0521, Reward: 3.8877
# Validation average reward after epoch 100: 3.8787
# Epoch [100/100], Batch [1501/2500], Actor Loss: -0.0111, Reward: 3.8988
# Validation average reward after epoch 100: 3.8784
# Epoch [100/100], Batch [1601/2500], Actor Loss: -0.0332, Reward: 3.8849
# Validation average reward after epoch 100: 3.8773
# Epoch [100/100], Batch [1701/2500], Actor Loss: -0.0473, Reward: 3.8885
# Validation average reward after epoch 100: 3.8772
# Epoch [100/100], Batch [1801/2500], Actor Loss: -0.0269, Reward: 3.8641
# Validation average reward after epoch 100: 3.8783
# Epoch [100/100], Batch [1901/2500], Actor Loss: -0.0423, Reward: 3.8884
# Validation average reward after epoch 100: 3.8781
# Epoch [100/100], Batch [2001/2500], Actor Loss: -0.0139, Reward: 3.8721
# Validation average reward after epoch 100: 3.8773
# Epoch [100/100], Batch [2101/2500], Actor Loss: -0.0571, Reward: 3.9096
# Validation average reward after epoch 100: 3.8807
# Epoch [100/100], Batch [2201/2500], Actor Loss: -0.0097, Reward: 3.8691
# Validation average reward after epoch 100: 3.8765
# Epoch [100/100], Batch [2301/2500], Actor Loss: -0.0469, Reward: 3.8999
# Validation average reward after epoch 100: 3.8809
# Epoch [100/100], Batch [2401/2500], Actor Loss: -0.0292, Reward: 3.8691
# Validation average reward after epoch 100: 3.8756
# Training completed!

# %%
print('Test started...')
test1(args, test_dataset)
print('Test completed!')
# Out:
# Test started...
# Test average reward: 3.8724
# Test completed!

# %%
# 测试 (sampling)
def sampling(actor, inputs, num_samples, sub_batch_size=1280):
    # inputs: (batch_size, seq_len, input_size)
    batch_size = inputs.size(0)
    best_idxs, best_rewards = [], []
    
    for i in range(batch_size):
        temp_input = inputs[i].unsqueeze(0)
        best_idx, best_reward = None, float('inf')
        
        num_sub_batches = (num_samples + sub_batch_size - 1) // sub_batch_size
        
        remaining_samples = num_samples
        for _ in range(num_sub_batches):
            current_batch_size = min(sub_batch_size, remaining_samples)
            remaining_samples -= current_batch_size
            
            temp_inputs = temp_input.repeat(current_batch_size, 1, 1)
            temp_rewards, temp_idxs, _ = actor(temp_inputs)
            
            sub_best_reward, sub_best_idx = temp_rewards.min(0)
            sub_best_reward = sub_best_reward.item()
            sub_best_idx = temp_idxs[sub_best_idx]
            
            if sub_best_reward < best_reward:
                best_idx = sub_best_idx
                best_reward = sub_best_reward
            
        best_idxs.append(best_idx)
        best_rewards.append(best_reward)
    
    return torch.tensor(best_rewards, device=inputs.device), torch.stack(best_idxs, dim=0).to(inputs.device)
        

def test2(args, test_dataset):
    test_loader = DataLoader(test_dataset, batch_size=args.batch_size, shuffle=False)
    
    actor = Actor(args.num_heads, args.embedding_size, args.num_layers, args.input_size, args.FF_hidden_size, args.normalization, args.dropout, args.C, 2.2, reward).to(args.device).to(args.device)
    actor.load_state_dict(torch.load(os.path.join(args.output_dir, args.name)))
    
    actor.eval()
    total_rewards, total_nums = 0, 0
    
    with torch.no_grad():
        for i, test_batch in enumerate(test_loader):
            inputs = test_batch.to(args.device)
            actor_rewards, idxs = sampling(actor, inputs, args.num_samples)
            total_rewards += actor_rewards.sum().item()
            total_nums += inputs.size(0)
            
            if i == 0 and inputs.size(0) >= 8:
                plot_tsp_paths(args, inputs[:8], idxs[:8], actor_rewards[:8])
            
    avg_reward = total_rewards / total_nums
    print(f"Test average reward (sampling): {avg_reward:.4f}")

# %%
print('Test started...')
test2(args, test_dataset)
print('Test completed!')
# Out:
# Test started...
# Test average reward (sampling): 3.8413
# Test completed!
